# %% [markdown]
# # Recommendation Systems (Popularity and Collaborative Filtering)

# %%
import pandas as pd
#importing the pandas library

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#importing the seaborn and matplotlib library

# %%
import numpy as np
from sklearn.model_selection import train_test_split
#importing numpy and train_test_split library

# %%
colnames=['Userid','Itemid','Ratings','TimeStamp']
#providing the column values to the dataset

# %%
ratings_data=pd.read_csv('ratings_Electronics.csv', names=colnames)
#reading the CSV file

# %%
ratings_data.shape
#Getting the shape of the dataset
# Out:
# (7824482, 4)

# %%
ratings_data.dtypes
#checking the data type for the dataset
# Out:
# Userid        object
# Itemid        object
# Ratings      float64
# TimeStamp      int64
# dtype: object

# %%
ratings_data.head()
#checking the first five rows using the head function
# Out:
#            Userid      Itemid  Ratings   TimeStamp
# 0   AKM1MP6P0OYPR  0132793040      5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944      5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341      1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341      3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341      1.0  1334707200

# %%
ratings_data.isnull().values.any()
#Checking If the dataset contains any null values
# Out:
# False

# %%
ratings_data['Userid'].value_counts()
#this gives us the unique users
# Out:
# A5JLAU2ARJ0BO     520
# ADLVFFE4VBT8      501
# A3OXHLG6DIBRW8    498
# A6FIAB28IS79      431
# A680RUE1FDO8B     406
# A1ODOGXEYECQQ8    380
# A36K2N527TXXJN    314
# A2AY4YUOX2N1BQ    311
# AWPODHOB4GFWL     308
# ARBKYIVNYWK3C     296
# A25C2M3QF9G7OQ    296
# A22CW0ZHY3NJH8    292
# A3EXWV8FNSSFL6    282
# A38RMU1Y5TDP9     282
# A3LGT6UZL99IW1    279
# A2NOW4U7W3F7RI    277
# A23GFTVIETX7DS    270
# A3PD8JD9L4WEII    266
# A17BUUBOU0598B    261
# A3AYSYSLHU26U9    257
# A2XRMQA6PJ5ZJ8    253
# A231WM2Z2JL0U3    252
# A12DQZKRKTNF5E    252
# A1UQBFCERIP7VJ    247
# AGVWTYW0ULXHT     244
# A203OCQQ12MAVT    240
# AEJAGHLC675A7     239
# A2NYK9KWFMJV4Y    238
# A3A4ZAIBQWKOZS    236
# A1T1YSCDW0PD25    227
#                  ...
# A39MG6QWPGBNZ7      1
# A3NOF8OVCNMCN0      1
# A22QHGNSH22ZUS      1
# A2KLU88CDXUYJ9      1
# A3DQE41C9U9MDJ      1
# AF6B5TNJXH20I       1
# A1282NPGGSQ0HU      1
# A3V5GS6KCHN0TA      1
# A1C976N1W1JD47      1
# A26KLH2KM047FR      1
# A12J5PUHG9B3NG      1
# A1YFHY9K2X6HH4      1
# A6NU4TFDJUJOX       1
# A2UNC7RO47VSXB      1
# A18X32L2M2FGQR      1
# ATA41DVK7WVGG       1
# A10FKC61LN1HR0      1
# A3GI5CYN546ZVS      1
# AP15TEKJR3U95       1
# A1E2QTJXJ5W4JD      1
# A1VROKQF1WR9KK      1
# A2JFIPRN3WLVLQ      1
# A1W1EC0OD7II4T      1
# A3NWVFX9DZK8YY      1
# A20H7DWI9VQ6C6      1
# A1I5S1JN59ZKJ8      1
# A2H9JN5AF99N5B      1
# A1ZBRMNGLRKF9Z      1
# A3BYKZEEK8VWV6      1
# A2D7EP31Q1YLJP      1
# Name: Userid, Length: 4201696, dtype: int64

# %%
ratings_data['Itemid'].value_counts()
#This shows us the different products in the data.
# Out:
# B0074BW614    18244
# B00DR0PDNE    16454
# B007WTAJTO    14172
# B0019EHU8G    12285
# B006GWO5WK    12226
# B003ELYQGG    11617
# B003ES5ZUU    10276
# B007R5YDYA     9907
# B00622AG6S     9823
# B0002L5R78     9487
# B008OHNZI0     8966
# B003LR7ME6     8840
# B000LRMS66     8715
# B009SYZ8OC     8370
# B00BGA9WK2     7561
# B004QK7HI8     7060
# B009A5204K     7059
# B00BGGDVOO     6893
# B0098F5W0Q     6616
# B002MAPRYU     6599
# B002WE6D44     6509
# B005HMKKH4     6134
# B0012S4APK     5642
# B0052YFYFK     5521
# B0001FTVEK     5345
# B0044YU60M     5239
# B00316263Y     5038
# B000I68BD4     4903
# B006ZP8UOW     4842
# B0041Q38NU     4774
#               ...
# B004C3V4EC        1
# B0000AI1EX        1
# B000LSJCIC        1
# B00478SMVU        1
# B004RC7ZL4        1
# B00H5HFAWY        1
# B008NNYVH4        1
# B004U2FSV0        1
# B00A3RXRLE        1
# B00A2V95N0        1
# B00C3DDDZG        1
# B0050I0E9O        1
# B0009Y6IIA        1
# B0002BG6JG        1
# B000HKMNNU        1
# B002COJ9ZO        1
# B008PJV77S        1
# B00AB4D6KG        1
# B00KATCXII        1
# B00J4CBO64        1
# B0055IK7GE        1
# B003RBPH8E        1
# B0057UB18I        1
# B004TGZTZ2        1
# B00805C316        1
# B00AV7JHK6        1
# B0000VSU7E        1
# B001S2PXJ2        1
# B004E6D878        1
# B00B3YQVGE        1
# Name: Itemid, Length: 476002, dtype: int64

# %%
ratings_data['Ratings'].value_counts()
# getting the unique ratings applied to different products
# Out:
# 5.0    4347541
# 4.0    1485781
# 1.0     901765
# 3.0     633073
# 2.0     456322
# Name: Ratings, dtype: int64

# %%
top_fifty=ratings_data.Userid.value_counts().rename_axis('UserId').reset_index(name="Rating count")
#getting the list of users and counting the times when the user had rated a product and showing it in descending order.

# %%
amazon_df=pd.DataFrame((ratings_data[ratings_data.Userid.isin(top_fifty[top_fifty['Rating count']>=50].UserId)]))
#getting the list of all the users who have rated more than 50 products

# %%
users=amazon_df['Userid'].unique()
#getting the list of unique users

# %%
train_data, test_data=train_test_split(amazon_df, test_size=0.30, random_state=0)
#using the train, test function to split the data into training and test data

# %% [markdown]
# ## We now use ways to sort the most popular products

# %%
train_data_grouped=train_data.groupby(['Itemid']).agg({'Userid': 'count'}).reset_index()
#Group the data by Products and sort by the user and get their count

# %%
train_data_grouped.rename(columns = {'Userid': 'score'},inplace=True)
#change the column name from userid to score

# %%
train_data_sort = train_data_grouped.sort_values(['score', 'Itemid'], ascending = [0,1])
#sort the values in terms of the score

# %%
train_data_sort['Rank'] = train_data_sort['score'].rank(ascending=0, method='first')
#create a new column called RANK and store the list of the ranks calculated

# %%
popularity_recommendations = train_data_sort.head(10)
# This stores the top 10 rated products

# %%
user_recommendations = popularity_recommendations
cols = user_recommendations.columns.tolist()
cols = cols[-1:] + cols[:-1]
user_recommendations = user_recommendations[cols]
# we then store the top rated products to a variable and then rearrange the rows such that the rank goes as the first columns.

# %%
user_recommendations
# Out:
#        Rank      Itemid  score
# 30847   1.0  B0088CJT4U    133
# 30287   2.0  B007WTAJTO    124
# 19647   3.0  B003ES5ZUU    122
# 8752    4.0  B000N99BBC    114
# 30555   5.0  B00829THK0     97
# 30559   6.0  B00829TIEK     97
# 17384   7.0  B002R5AM7C     94
# 31107   8.0  B008DWCRQW     91
# 17573   9.0  B002SZEOLG     84
# 22744  10.0  B004CLYEDC     82

# %% [markdown]
# # Collaborative based filtering model

# %%
from surprise import Reader, Dataset
#importing the Surprise library

# %%
reader=Reader(rating_scale=(1,5))
#initialising the READER object

# %%
data=Dataset.load_from_df(amazon_df[['Userid', 'Itemid','Ratings']], reader)
#adding the dataset to the Dataset object with the Userid, Itemid and the ratings and also passing the reader as the object.

# %%
data
#data is now a SURPRISE object.

# %%
from surprise.model_selection import train_test_split
#importing train-test-split function from surprise

# %%
trainset, testset = train_test_split(data,test_size=.30, random_state=1233)
#Using the train-test split function to split the data in the ratio 70:30

# %%
trainset
#Trainset again is a surprise object

# %%
from surprise import KNNWithMeans
#importing KNNwithMeans from the surprise library

# %%
from surprise import accuracy
#importing accuracy from Surprise library

# %%
from surprise import Prediction
#importing prediction from surprise library

# %%
algo=KNNWithMeans(51, sim_options={'name':'pearson', 'user_based': True})
#Creating the model with the vale of K=51 and the model being a user-user similarity model.

# %%
algo.fit(trainset)
#fitting the training set to the model
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
len(testset)
#calculating the length of the test set.
# Out:
# 37762

# %%
test_pred=algo.test(testset)
#getting the predictions of the test set and storing it in a vairable called test_pred

# %%
test_pred[5]
# checking the recommendation for a userid with an itemid
# Out:
# Prediction(uid='A3V6QSTG2T9MIO', iid='B00829TIEK', r_ui=5.0, est=4.985848628463074, details={'actual_k': 2, 'was_impossible': False})

# %%
test_pred_df=pd.DataFrame(test_pred)
#passing the predictions to a dataframe

# %%
test_pred_df
# Out:
#                   uid         iid  r_ui       est  \
# 0       AHR86ZEYETLJI  B0073HSH8U   5.0  4.522388
# 1      A3PD8JD9L4WEII  B0085BR4RS   5.0  4.265989
# 2      A3GX0FAMEXV6FB  B007PJ4Q4A   4.0  4.045455
# 3        ADLVFFE4VBT8  B002QQ7TLY   5.0  4.385184
# 4      A2HKUM9OEBQKDW  B006Z0Q2SI   5.0  4.183673
# 5      A3V6QSTG2T9MIO  B00829TIEK   5.0  4.985849
# 6      A2JXS1JII6SAUD  B009HP42HQ   5.0  4.607843
# 7      A38Z6QG6988WS7  B008YQAFH0   5.0  4.857143
# 8      A1SX9PHJWTDMF9  B000O8I474   5.0  4.733333
# 9      A2BYV7S1QP2YIG  B007IFVSYM   5.0  4.265989
# 10      A680RUE1FDO8B  B000V1VG4W   4.0  4.265989
# 11     A2RIXSMGE9VIBG  B003MHUN7S   2.0  3.906250
# 12     A35Q0RBM3YNQNF  B00G4V0QSK   5.0  4.726531
# 13     A3TAS1AG6FMBQW  B007AHJNF4   5.0  4.791962
# 14      ARX0KOX5Q01BJ  B000LSKBP0   4.0  3.642857
# 15     A2ZRMCRLDSUX6R  B001RCTATW   3.0  4.265989
# 16     A2GKMXRLI7KLFP  B0035FIS2O   5.0  4.265989
# 17     A2NYK9KWFMJV4Y  B00CJRZ31S   5.0  4.405795
# 18     A3DQWFWINN3V5A  B00429N18S   5.0  4.514474
# 19     A2HMF8ZR67BNZS  B000ZD0CV4   5.0  4.697917
# 20     A1UEL5C1N6E5SE  B00009W43G   2.0  4.265989
# 21     A2WC9NFLG57W4H  B00ATM1MGA   4.0  4.944774
# 22     A33HIV8RXRDM88  B00BFYVXYM   3.0  2.886047
# 23     A18S2VGUH9SCV5  B002RJSSOM   4.0  4.265989
# 24     A14Z6D3IRJ23F7  B000ZEK45M   5.0  4.265989
# 25       ADLVFFE4VBT8  B00BZC31WQ   4.0  4.132836
# 26     A1W415JP5WEAJK  B005IMFX2K   5.0  5.000000
# 27      A8X478DM3KAWM  B006GLHEO2   5.0  4.265989
# 28     A3NKRH3TJ4DPVI  B000F9YN22   5.0  5.000000
# 29      ATOKT8QYK967L  B00009R6K7   4.0  4.162162
# ...               ...         ...   ...       ...
# 37732   AY3XPKRAMKKY7  B004TLH7C0   4.0  4.368421
# 37733  A10ZFE6YE0UHW8  B00H7FYEPI   4.0  4.441260
# 37734  A3V6QSTG2T9MIO  B003ZX8B2S   3.0  4.285714
# 37735   ADKGE078JK8K7  B002UVM3A2   5.0  4.265989
# 37736   AYB4ELCS5AM8P  B000067SOH   5.0  4.803922
# 37737  A25UZ7MA72SMKM  B00313JD06   5.0  4.164384
# 37738  A1Z7U9K6X3FEOU  B000C1Z0HA   4.0  4.411765
# 37739  A2BMZRO0H7TFCS  B003JZCE7U   3.0  4.265989
# 37740  A2ZDY0V4Q1SZD7  B003VAGXZC   5.0  4.416667
# 37741   AGX2K0FMS0IVL  B004I5ERUW   5.0  4.019231
# 37742  A38NELQT98S4H8  B008DWCRQW   4.0  4.606378
# 37743  A3OA4DV4L81N1D  B000L8CNAG   5.0  4.571429
# 37744  A2ZRMCRLDSUX6R  B00IG54NXG   5.0  4.545455
# 37745   AAW7X3GRD8GY9  B00BQ4F9ZA   4.0  4.414634
# 37746  A2RU4U1JZ3DMP5  B0002RBQO0   4.0  4.279412
# 37747   AIFLY2HF8NS8U  B00AYQ433U   4.0  4.490909
# 37748  A2EF8N7ZE7ONWX  B000X4PJG8   3.0  4.105263
# 37749  A28525P0S5ZVJ3  B002UK2QBE   2.0  4.265989
# 37750  A3KNGMX2RVQG91  B0000WKYU4   5.0  4.390244
# 37751   A28P7V9KI7MXP  B004IUOFKO   3.0  4.265989
# 37752   AN9CP6J4JF91X  B000QUUFRW   5.0  4.600000
# 37753  A1WXG10FJ353K0  B000Y4AH3C   5.0  4.237288
# 37754   AQNSQW4495SG0  B001ANT1I8   5.0  4.265989
# 37755   AL9WKVMRI6GFB  B003VQQVDU   4.0  4.265989
# 37756  A2294LS59GC5K7  B006HZJXQ4   3.0  4.265989
# 37757  A1KDUQ2HU0WD68  B00G5RDU5O   5.0  4.067795
# 37758  A15TABNGK6L4N3  B002SA9N8K   5.0  4.265989
# 37759  A3KNGMX2RVQG91  B004GF8TIK   5.0  5.000000
# 37760  A3EZFFPVS34AMO  B0042VSTZQ   3.0  4.586207
# 37761  A2CL818RN52NWN  B00018WNSI   4.0  4.265989
#
#                                                  details
# 0               {'actual_k': 0, 'was_impossible': False}
# 1      {'was_impossible': True, 'reason': 'User and/o...
# 2               {'actual_k': 0, 'was_impossible': False}
# 3               {'actual_k': 3, 'was_impossible': False}
# 4               {'actual_k': 0, 'was_impossible': False}
# 5               {'actual_k': 2, 'was_impossible': False}
# 6               {'actual_k': 0, 'was_impossible': False}
# 7               {'actual_k': 0, 'was_impossible': False}
# 8               {'actual_k': 0, 'was_impossible': False}
# 9      {'was_impossible': True, 'reason': 'User and/o...
# 10     {'was_impossible': True, 'reason': 'User and/o...
# 11              {'actual_k': 0, 'was_impossible': False}
# 12              {'actual_k': 7, 'was_impossible': False}
# 13              {'actual_k': 2, 'was_impossible': False}
# 14              {'actual_k': 0, 'was_impossible': False}
# 15     {'was_impossible': True, 'reason': 'User and/o...
# 16     {'was_impossible': True, 'reason': 'User and/o...
# 17              {'actual_k': 1, 'was_impossible': False}
# 18              {'actual_k': 1, 'was_impossible': False}
# 19              {'actual_k': 0, 'was_impossible': False}
# 20     {'was_impossible': True, 'reason': 'User and/o...
# 21              {'actual_k': 3, 'was_impossible': False}
# 22              {'actual_k': 1, 'was_impossible': False}
# 23     {'was_impossible': True, 'reason': 'User and/o...
# 24     {'was_impossible': True, 'reason': 'User and/o...
# 25              {'actual_k': 8, 'was_impossible': False}
# 26              {'actual_k': 2, 'was_impossible': False}
# 27     {'was_impossible': True, 'reason': 'User and/o...
# 28              {'actual_k': 1, 'was_impossible': False}
# 29              {'actual_k': 0, 'was_impossible': False}
# ...                                                  ...
# 37732           {'actual_k': 0, 'was_impossible': False}
# 37733           {'actual_k': 2, 'was_impossible': False}
# 37734           {'actual_k': 0, 'was_impossible': False}
# 37735  {'was_impossible': True, 'reason': 'User and/o...
# 37736           {'actual_k': 0, 'was_impossible': False}
# 37737           {'actual_k': 0, 'was_impossible': False}
# 37738           {'actual_k': 0, 'was_impossible': False}
# 37739  {'was_impossible': True, 'reason': 'User and/o...
# 37740           {'actual_k': 0, 'was_impossible': False}
# 37741           {'actual_k': 0, 'was_impossible': False}
# 37742           {'actual_k': 8, 'was_impossible': False}
# 37743           {'actual_k': 0, 'was_impossible': False}
# 37744           {'actual_k': 0, 'was_impossible': False}
# 37745           {'actual_k': 0, 'was_impossible': False}
# 37746           {'actual_k': 0, 'was_impossible': False}
# 37747           {'actual_k': 0, 'was_impossible': False}
# 37748           {'actual_k': 0, 'was_impossible': False}
# 37749  {'was_impossible': True, 'reason': 'User and/o...
# 37750           {'actual_k': 0, 'was_impossible': False}
# 37751  {'was_impossible': True, 'reason': 'User and/o...
# 37752           {'actual_k': 0, 'was_impossible': False}
# 37753           {'actual_k': 0, 'was_impossible': False}
# 37754  {'was_impossible': True, 'reason': 'User and/o...
# 37755  {'was_impossible': True, 'reason': 'User and/o...
# 37756  {'was_impossible': True, 'reason': 'User and/o...
# 37757           {'actual_k': 4, 'was_impossible': False}
# 37758  {'was_impossible': True, 'reason': 'User and/o...
# 37759           {'actual_k': 1, 'was_impossible': False}
# 37760           {'actual_k': 0, 'was_impossible': False}
# 37761  {'was_impossible': True, 'reason': 'User and/o...
#
# [37762 rows x 5 columns]

# %%
algo.predict(uid='AQNSQW4495SG0',iid='B002SA9N8K')
#using the model to predict the recommendation settings for a userid and an item. In this case, the user would not be recommended the item.
# Out:
# Prediction(uid='AQNSQW4495SG0', iid='B002SA9N8K', r_ui=None, est=4.265988718519107, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'})

# %% [markdown]
# # Calculating the accuracy for the collaborative model

# %%
# we use the accuracy library from the surprise package and use the rmse as a metric
accuracy.rmse(test_pred)
# Out:
# RMSE: 1.0582
# 1.0581779546301344

# %% [markdown]
# # Get top - K ( K = 5) recommendations.

# %%
testset_new=trainset.build_anti_testset()
# creating a testset out of the training data

# %%
len(testset_new)
#checking the length of the dataset
# Out:
# 58652111

# %%
testset_new[0:5]
#getting the top 5 recommendations
# Out:
# [('A30JPZ9TZ7I61U', 'B0017KH6OU', 4.265988718519107),
#  ('A30JPZ9TZ7I61U', 'B001VFUN82', 4.265988718519107),
#  ('A30JPZ9TZ7I61U', 'B00009W3SK', 4.265988718519107),
#  ('A30JPZ9TZ7I61U', 'B00B9BUZW2', 4.265988718519107),
#  ('A30JPZ9TZ7I61U', 'B0076POAOE', 4.265988718519107)]

# %%
predictions=algo.test(testset_new[0:10000])
#using the algorithm to test the first 10000 items

# %%
predictions_df=pd.DataFrame([[x.uid,x.iid,x.est] for x in predictions])
#storing the userid, itemid and the established ratings to a dataframe

# %%
predictions_df.head()
#checking the dataframe
# Out:
#                 0           1         2
# 0  A30JPZ9TZ7I61U  B0017KH6OU  4.416667
# 1  A30JPZ9TZ7I61U  B001VFUN82  3.752521
# 2  A30JPZ9TZ7I61U  B00009W3SK  4.416667
# 3  A30JPZ9TZ7I61U  B00B9BUZW2  4.416667
# 4  A30JPZ9TZ7I61U  B0076POAOE  4.416667

# %%
predictions_df.columns=['Userid','Productid','est_rating']
#Adding the column names

# %%
predictions_df.head()
# chekcing the data
# Out:
#            Userid   Productid  est_rating
# 0  A30JPZ9TZ7I61U  B0017KH6OU    4.416667
# 1  A30JPZ9TZ7I61U  B001VFUN82    3.752521
# 2  A30JPZ9TZ7I61U  B00009W3SK    4.416667
# 3  A30JPZ9TZ7I61U  B00B9BUZW2    4.416667
# 4  A30JPZ9TZ7I61U  B0076POAOE    4.416667

# %%
predictions_df.sort_values(by=['Userid','est_rating'], ascending=False, inplace=True)
#sorting the values by userid and the ratings

# %%
predictions_df.head()
# Out:
#             Userid   Productid  est_rating
# 22  A30JPZ9TZ7I61U  B00HFRWWAM         5.0
# 28  A30JPZ9TZ7I61U  B0015DYMVO         5.0
# 29  A30JPZ9TZ7I61U  B000LP0R3E         5.0
# 34  A30JPZ9TZ7I61U  B0062XB9FE         5.0
# 63  A30JPZ9TZ7I61U  B000IF51UQ         5.0

# %%
top_5_recos=predictions_df.groupby('Userid').head(5).reset_index(drop=True)
#getting the top 5 recommendations

# %%
top_5_recos
# the top 5 recommendations for the user.
# Out:
#            Userid   Productid  est_rating
# 0  A30JPZ9TZ7I61U  B00HFRWWAM         5.0
# 1  A30JPZ9TZ7I61U  B0015DYMVO         5.0
# 2  A30JPZ9TZ7I61U  B000LP0R3E         5.0
# 3  A30JPZ9TZ7I61U  B0062XB9FE         5.0
# 4  A30JPZ9TZ7I61U  B000IF51UQ         5.0

# %% [markdown]
# # Insights

# %% [markdown]
# ### Based on this project, we have created two recommender systems, the first one is a popularity based recommender system and the second one is a collaborative filtering model. Both these models are different, the popularity based recommender system recommends the most popular products to all the users whereas the collaborative model uses two approaches for, the first one being item based and the second one being user based. We have used a 'user' based collaborative filtering model.

# %% [markdown]
# ### No of users: 4201696

# %% [markdown]
# ### No of products: 476002

# %% [markdown]
# ### Rating scale: 1 to 5

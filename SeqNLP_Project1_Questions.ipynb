# %% [markdown]
# # Sentiment Classification
#
#
# ### Generate Word Embeddings and retrieve outputs of each layer with Keras based on Classification task
#
# Word embeddings are a type of word representation that allows words with similar meaning to have a similar representation.
#
# It is a distributed representation for text that is perhaps one of the key breakthroughs for the impressive performance of deep learning methods on challenging natural language processing problems.
#
# We willl use the imdb dataset to learn word embeddings as we train our dataset. This dataset contains 25,000 movie reviews from IMDB, labeled with sentiment (positive or negative).
#
#
#
# ### Dataset
#
# `from keras.datasets import imdb`
#
# Dataset of 25,000 movies reviews from IMDB, labeled by sentiment (positive/negative). Reviews have been preprocessed, and each review is encoded as a sequence of word indexes (integers). For convenience, the words are indexed by their frequency in the dataset, meaning the for that has index 1 is the most frequent word. Use the first 20 words from each review to speed up training, using a max vocab size of 10,000.
#
# As a convention, "0" does not stand for a specific word, but instead is used to encode any unknown word.
#
#
# ### Aim
#
# 1. Import test and train data
# 2. Import the labels ( train and test)
# 3. Get the word index and then Create key value pair for word and word_id. (12.5 points)
# 4. Build a Sequential Model using Keras for Sentiment Classification task. (10 points)
# 5. Report the Accuracy of the model. (5 points)
# 6. Retrive the output of each layer in keras for a given single test sample from the trained model you built. (2.5 points)

# %% [markdown]
# #### Usage:

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import numpy as np
# Out:
# TensorFlow 2.x selected.

# %%
from tensorflow.keras.datasets import imdb

vocab_size = 10000 

#vocab size

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size) # vocab_size is no.of words to consider from the dataset, ordering based on frequency.

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
vocab_size = 10000 #vocab size
maxlen = 300  #number of word used from each review

# %%
#load dataset as a list of ints
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)
#make all sequences of the same length
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test =  pad_sequences(x_test, maxlen=maxlen)

# %%
word_index = imdb.get_word_index()

# %%
word_dict=dict()
for word, word_id in word_index.items():
  print(word_id, word)
  word_dict[word]=word_id
# Out:
# Streaming output truncated to the last 5000 lines.
# (70044, u'threadid')
# (30392, u'accessory')
# (58725, u"a'vuchella")
# (51357, u'sputnick')
# (25132, u'aisles')
# (19303, u'employers')
# (30393, u'piloted')
# (51359, u"joanie's")
# (5118, u'omen')
# (45436, u'wounder')
# (48138, u"madhavi's")
# (86499, u'holdouts')
# (86500, u"'george'")
# (30394, u'instills')
# (4413, u'switch')
# (2042, u'african')
# (30395, u'hassan')
# (86501, u'hilarities')
# (48428, u"meyerling's")
# (3081, u'credible')
# (88255, u'cutoff')
# (86502, u"development'")
# (73997, u'eniemy')
# (27497, u'seizing')
# (86504, u"schnaas's")
# (30042, u'telekinesis')
# (86505, u'spinoff')
# (88256, u"montage's")
# (34468, u"natalie's")
# (6531, u'irene')
# (86507, u'irresolute')
# (51360, u'denials')
# (86508, u'robald')
# (86509, u"'discovering")
# (20537, u'yorkshire')
# (86510, u'reevaluated')
# (40483, u'tweety')
# (11292, u'ours')
# (86511, u'ripsnorting')
# (86512, u'ourt')
# (86514, u'sisyphean')
# (34469, u'janeiro')
# (6698, u'sarcastic')
# (88258, u'hatcheck')
# (86515, u"cacoyannis'")
# (86516, u"tywker's")
# (23304, u'kkk')
# (86517, u"alexandra's")
# (8766, u'developments')
# (86518, u"grail'")
# (57443, u'stanislav')
# (86520, u"collaboration's")
# (51361, u'bolshevik')
# (21830, u'begley')
# (17388, u'liberating')
# (23305, u'zabalza')
# (51362, u'arlette')
# (34470, u'parton')
# (51363, u'profiling')
# (86522, u'ranna')
# (86523, u'dreamboat')
# (51364, u"party's")
# (86524, u'ceta')
# (27498, u'arletty')
# (86525, u'homme')
# (81948, u'\x85much')
# (86526, u'martyn')
# (86527, u'legitimates')
# (86528, u'legitimated')
# (34471, u'blubber')
# (86529, u'prinze')
# (8051, u'dominate')
# (86530, u'haydn')
# (86531, u'mercantile')
# (86532, u'bootlegged')
# (86533, u'underproduced')
# (2639, u'california')
# (51365, u'bagatelle')
# (21036, u'motionless')
# (12982, u'surrealistic')
# (86534, u"dingman's")
# (40484, u'standby')
# (51366, u'tigra')
# (86535, u"dangerously's")
# (86536, u'lyndsay')
# (51367, u'ministro')
# (83251, u'habitaci\xf3n')
# (51369, u'sufferance')
# (69918, u'chote')
# (86537, u'philosophizes')
# (15470, u'americana')
# (86538, u"sequel'")
# (36971, u'prepped')
# (86539, u'nativity')
# (51370, u'oafs')
# (86540, u'philosophized')
# (1528, u'americans')
# (25133, u'signifies')
# (75804, u"'hetero")
# (86541, u'oafy')
# (40485, u'extrovert')
# (86542, u"'shower")
# (48499, u'parvarish')
# (3048, u'personalities')
# (70054, u"'donation'")
# (86545, u'inflight')
# (86546, u"scot's")
# (12243, u'escort')
# (9647, u'mining')
# (19307, u'watergate')
# (86547, u'aimanov')
# (70827, u"bustin'")
# (25134, u'watling')
# (21831, u"robbins'")
# (51371, u'embraceable')
# (86548, u'kermy')
# (86549, u'yaarrrghhh')
# (3594, u'relative')
# (86551, u'procedurals')
# (86552, u'quotidian')
# (51372, u'curdled')
# (11573, u'mutilation')
# (86553, u'scaffoldings')
# (70056, u'dinsey')
# (86555, u'freakness')
# (49181, u'seventies\x85')
# (86556, u'dass')
# (26893, u'mellisa')
# (23307, u'fabio')
# (8416, u'dash')
# (6532, u'spectacle')
# (73960, u'mich\xe9al')
# (86558, u"morrill's")
# (86559, u'mainsprings')
# (131, u'these')
# (51373, u'clung')
# (86561, u'gamboling')
# (40486, u'ladened')
# (34472, u'wasters')
# (65853, u'brrrrrrr')
# (86562, u'softporn')
# (11022, u'chiller')
# (51374, u'glamourpuss')
# (86563, u'cluny')
# (86564, u'vomitory')
# (3763, u'norman')
# (1713, u'theatre')
# (1277, u'normal')
# (86565, u'luddites')
# (1325, u'pieces')
# (40487, u"filmdom's")
# (86566, u'actingwise')
# (40488, u'blackest')
# (88272, u'embarasses')
# (10079, u'hardships')
# (51375, u'larner')
# (86567, u'overcranked')
# (74456, u'polluters')
# (51376, u"lamas'")
# (51377, u'rolando')
# (86568, u'1h53')
# (81794, u'ruptures')
# (86570, u'caprican')
# (7361, u'precise')
# (86571, u'jarome')
# (86572, u'medalist')
# (86573, u"reconstruction'")
# (22902, u"killer'")
# (86575, u'adolfo')
# (86576, u'midts')
# (30396, u'moderator')
# (37719, u"forrest's")
# (51378, u'aventura')
# (10298, u'therapist')
# (86578, u'demonstrator')
# (86579, u"'baby'")
# (51379, u'pendanski')
# (15471, u'crane')
# (86580, u'haryanavi')
# (86581, u'rexes')
# (86582, u'lauder')
# (86583, u'principality')
# (40489, u'soliciting')
# (14331, u'lauded')
# (86584, u'krebs')
# (86585, u'dechifered')
# (20538, u'incredulous')
# (86586, u'woundings')
# (86587, u'questmaster')
# (82268, u"gayle's")
# (20539, u'roadkill')
# (86589, u"ugh's")
# (11574, u'policies')
# (23309, u'contracts')
# (40490, u"mala's")
# (86590, u"brak's")
# (57453, u'proyect')
# (21832, u'repo')
# (51380, u'aaker')
# (86591, u"akhras'")
# (2176, u'killers')
# (30397, u'hotshot')
# (88277, u'soutendjik')
# (34473, u'marooned')
# (51891, u'astounds')
# (21833, u'dianne')
# (86593, u'prudery')
# (47791, u'ad\xe8le')
# (7791, u'finishing')
# (66763, u"billionaire's")
# (18455, u'caller')
# (40491, u'milling')
# (86594, u'workweeks')
# (40492, u'cologne')
# (86595, u'pleasently')
# (51382, u'heisei')
# (11023, u'kermit')
# (86596, u'lithographer')
# (51383, u'idioterne')
# (86597, u'trainspotter')
# (7907, u'scarlett')
# (34474, u'melton')
# (51384, u'gantlet')
# (86598, u'enumerates')
# (1991, u'gags')
# (51607, u'torpedoing')
# (51385, u'repertoires')
# (86600, u'pertfectly')
# (9221, u'gage')
# (40493, u'vanne')
# (86601, u'harharhar')
# (40765, u"'plan")
# (51386, u'enumerated')
# (86602, u"'stuff")
# (51387, u'moaned')
# (21834, u'whispered')
# (19446, u'promiscuity')
# (5650, u'campaign')
# (86603, u'kristan')
# (86604, u'cartwheel')
# (4066, u'parent')
# (51388, u'saigon')
# (41563, u'diagnoses')
# (17588, u'pained')
# (34475, u'countenance')
# (24528, u'stroking')
# (86606, u'philharmoniker')
# (77371, u'snowbell')
# (86607, u'harpsichordist')
# (5168, u'singers')
# (13401, u'grisby')
# (77375, u'painer')
# (34476, u'ringleader')
# (82555, u'vanderpool')
# (51390, u"'gangsta'")
# (86608, u'throughline')
# (15472, u'trades')
# (25135, u'dedicate')
# (51391, u'patroni')
# (86609, u'cheezoid')
# (15473, u'patrons')
# (54218, u"shakti's")
# (30398, u'orchestration')
# (25136, u'traded')
# (25137, u'terse')
# (10299, u'maintained')
# (16779, u'grants')
# (86610, u'arcades')
# (86612, u'clockwatchers')
# (30399, u'cluelessness')
# (27499, u'peyton')
# (86613, u'unopened')
# (86614, u'unintelligble')
# (39907, u'encryption')
# (86616, u'heathcliffe')
# (86617, u"gail's")
# (86618, u"'accidental'")
# (86619, u'dadaist')
# (86620, u'melnick')
# (27500, u'eros')
# (86621, u'hellbreeder')
# (86622, u'imtiaz')
# (86623, u'forgetaboutit')
# (4481, u'motivations')
# (80348, u"'gremlins'")
# (86624, u'cocoons')
# (23312, u'gander')
# (86625, u'nasuem')
# (15474, u'gripped')
# (86626, u"3000'")
# (86627, u'precipitate')
# (14883, u"dexter's")
# (77476, u'theatregoers')
# (86628, u'derris')
# (25138, u'stacked')
# (51393, u'waalkes')
# (51394, u"''saint")
# (82295, u'sayang')
# (19447, u'geronimo')
# (48650, u"'stargate")
# (86630, u'geronimi')
# (86631, u'derric')
# (86632, u"reynaud's")
# (86633, u'login')
# (86634, u'taverns')
# (25139, u'beales')
# (51395, u'hiram')
# (86635, u'miswrote')
# (6430, u'characteristics')
# (25140, u'cluster')
# (51396, u"runnin'")
# (7908, u'dangerously')
# (48659, u'traffickers')
# (86637, u'gangfights')
# (2931, u'obnoxious')
# (2902, u'everyday')
# (86638, u"heimlich's")
# (14884, u'pap')
# (34477, u'globetrotting')
# (77521, u'hohokam')
# (13859, u'pas')
# (3329, u'pat')
# (86639, u'pav')
# (34478, u'paw')
# (34479, u'pax')
# (987, u'pay')
# (24658, u'edwin')
# (21835, u'horatio')
# (86640, u'stepper')
# (86641, u"mainetti's")
# (23313, u'heirs')
# (86642, u'theocratic')
# (12983, u'acquaintances')
# (6884, u'pad')
# (86643, u'surrealness')
# (86644, u"hamlisch's")
# (21163, u'1900s')
# (86645, u'pai')
# (9648, u'stepped')
# (30400, u'pak')
# (4842, u'pal')
# (75820, u'posturings')
# (4378, u'pan')
# (40496, u'meaningfully')
# (51398, u'voss')
# (86646, u'seagulls')
# (617, u'running')
# (86647, u"showerman's")
# (27501, u'stairwell')
# (30402, u"locke's")
# (86648, u'frigon')
# (86649, u'profund')
# (86650, u'ozric')
# (86651, u'markup')
# (19487, u'tentative')
# (37769, u'mortgages')
# (86652, u'poliwhirl')
# (51399, u'pummels')
# (40498, u"maddin's")
# (86653, u'poldark')
# (88289, u'connoisseurship')
# (51400, u'haine')
# (86654, u'lysol')
# (6277, u'gates')
# (34481, u'gwar')
# (51401, u'clogging')
# (27502, u"demme's")
# (86655, u"shawnham's")
# (34482, u'toymaker')
# (40499, u"gundam's")
# (86656, u'sanitariums')
# (86657, u'gnostics')
# (86658, u"'chairman'")
# (86659, u"mo'")
# (86660, u'comeon')
# (86661, u'izes')
# (77617, u'shying')
# (34483, u'doctoral')
# (86662, u'praskins')
# (86663, u'recopies')
# (30056, u"burroughs'")
# (12984, u'mcdonald')
# (86664, u'lehch')
# (86665, u'japanse')
# (23315, u"summer's")
# (15475, u'crocodiles')
# (86666, u'massaccesi')
# (86667, u'rageddy')
# (51403, u'maughan')
# (86668, u'gatesville')
# (12587, u'maugham')
# (4073, u'careers')
# (51404, u'defected')
# (86669, u'moy')
# (86670, u'scrounges')
# (34484, u'mor')
# (25141, u'mop')
# (30404, u'mow')
# (77667, u'mou')
# (77670, u'mot')
# (51405, u'mok')
# (20541, u'moi')
# (18456, u'moh')
# (51406, u'moo')
# (16085, u'mon')
# (1630, u'mom')
# (6255, u'mol')
# (3021, u'mob')
# (6785, u'aiming')
# (30405, u'mog')
# (86671, u'claiborne')
# (19448, u'mod')
# (86672, u"'exploitation'")
# (81845, u'illiterates')
# (86673, u'militarize')
# (24270, u"\x8ei\x9eek's")
# (86674, u'lelliott')
# (86675, u"career'")
# (81805, u"'drugstore")
# (86677, u"tcm's")
# (11907, u'miraculous')
# (1101, u'laughing')
# (86678, u"'budget'")
# (86679, u'taji')
# (21836, u'fulfil')
# (51407, u'undifferentiated')
# (47295, u'tatou')
# (86680, u'savitch')
# (63668, u'blindsight')
# (86681, u'turnbill')
# (86682, u'stumpfinger')
# (20542, u'featurettes')
# (34486, u'fidani')
# (86683, u'gleanings')
# (30408, u'organizing')
# (86684, u'phoenicia')
# (30409, u'octane')
# (40502, u'besser')
# (86685, u'hamatova')
# (30143, u'attractively')
# (2084, u'overly')
# (21653, u'technicalities')
# (86686, u'rempit')
# (9252, u'expressing')
# (6885, u'aussie')
# (48153, u"goodness'")
# (86688, u'shitfaced')
# (86689, u"'radicalism'")
# (40503, u'wkrp')
# (86690, u'aaaaatch')
# (25142, u'dimensionally')
# (86691, u'supressing')
# (86692, u"hannan's")
# (86693, u'scathed')
# (17589, u'kyoto')
# (77778, u'jennings')
# (86694, u"haack's")
# (3732, u'notably')
# (11140, u'bernie')
# (40504, u'manufactures')
# (86695, u'weybridge')
# (23316, u'preoccupied')
# (86696, u"b2's")
# (51409, u'contagion')
# (14748, u'roar')
# (86697, u"'free")
# (88297, u'everone')
# (86698, u'roan')
# (12574, u'airline')
# (15477, u'roam')
# (3949, u'sadistic')
# (27503, u'wittiness')
# (21482, u'donut')
# (1317, u'road')
# (86699, u'waimea')
# (5338, u'quietly')
# (51412, u'shoplifting')
# (78917, u'isabelle\x85')
# (26035, u'furnace')
# (86701, u'amasses')
# (20543, u'auschwitz')
# (86703, u'uptown')
# (86704, u'follett')
# (40506, u'amassed')
# (51413, u'wildfire')
# (86705, u"intense'")
# (11294, u'gunfight')
# (27504, u'gussie')
# (21837, u'downed')
# (86706, u'3th')
# (19450, u'styling')
# (40507, u'compliant')
# (86707, u'elbowing')
# (8767, u'lions')
# (86708, u'rajendranath')
# (29708, u"preston's")
# (3788, u'hysterical')
# (86709, u'downes')
# (12985, u'downer')
# (40508, u'gruver')
# (7532, u'stereotyped')
# (21526, u'unsettled')
# (23317, u'improvising')
# (51414, u'duchy')
# (39065, u'esqe')
# (86710, u"majors'")
# (34487, u'trintignant')
# (596, u'gore')
# (27506, u"alexander's")
# (34488, u'semetary')
# (75828, u"shows'")
# (86711, u'unsettles')
# (40509, u'goro')
# (9078, u'flamboyant')
# (48777, u'clunkier')
# (86712, u'langrishe')
# (86713, u"'mel")
# (5839, u"brother's")
# (32587, u'merges')
# (3107, u'dubbing')
# (5496, u'affection')
# (60844, u"vall\xe9e's")
# (57301, u'cusamanos')
# (12588, u'goebbels')
# (27507, u'cables')
# (9388, u'mastroianni')
# (86716, u"partner'")
# (86717, u'sacrificies')
# (86718, u'malacici')
# (51417, u'lanier')
# (25143, u'tripods')
# (43059, u'cleanup')
# (51418, u"boon'")
# (23318, u'thames')
# (51419, u'shriners')
# (86720, u"cast'")
# (17590, u'outfield')
# (86721, u'profes')
# (34489, u'lousiest')
# (40510, u'potch')
# (86722, u'pukey')
# (86723, u"reems's")
# (39079, u'pukes')
# (18457, u"leonard's")
# (51420, u'dwarfing')
# (86724, u'shatta')
# (40511, u'princesse')
# (86725, u"protaganiste's")
# (48796, u'dunked')
# (86727, u"emma'")
# (34490, u'prudent')
# (86729, u'boons')
# (23319, u'temptress')
# (86730, u"shooting's")
# (25144, u'consternation')
# (6038, u'casts')
# (86731, u'unselfishness')
# (86732, u'refutation')
# (86733, u'iqubal')
# (12589, u'boone')
# (30411, u'craftsmen')
# (40360, u'the\x85')
# (86734, u'adjutant')
# (86735, u"tisserand's")
# (20544, u'sergei')
# (73643, u'sergej')
# (856, u'forget')
# (66297, u'\u2018dr')
# (86736, u'disassembled')
# (86737, u"explaining'")
# (86738, u"palookaville'")
# (86739, u"housesitter'")
# (21838, u'forged')
# (86740, u'puchase')
# (40513, u"translation'")
# (86742, u'sacrilage')
# (51421, u'kampung')
# (86743, u'serges')
# (34491, u'sleazeball')
# (86744, u"pelle's")
# (34492, u'karamchand')
# (83971, u'cinephilia')
# (30413, u'parcel')
# (40515, u'bowers')
# (86746, u'klienfelt')
# (27508, u'translations')
# (50617, u'hanz\xf4')
# (39742, u"mayer's")
# (86747, u'riviting')
# (86748, u'musseum')
# (86749, u"johar's")
# (86750, u'sezuan')
# (86751, u'monro')
# (51422, u'unexpurgated')
# (16781, u'stamos')
# (86752, u'poolguy')
# (10774, u'broderick')
# (78085, u'trustful')
# (78088, u'gitwisters')
# (4414, u'celebrity')
# (86753, u'khemmu')
# (40516, u'worded')
# (66948, u'filiality')
# (51424, u'invigorate')
# (88305, u'torin')
# (51425, u'embarrasing')
# (40145, u'they\xb4re')
# (30414, u'knifes')
# (86754, u"'grow")
# (6138, u'crashes')
# (74383, u'really\x85')
# (34493, u"'tulip'")
# (86755, u'ventimiglia')
# (51426, u'knifed')
# (51427, u'preordained')
# (1034, u'further')
# (40518, u'largesse')
# (25817, u'ave')
# (3897, u'abc')
# (12244, u'abe')
# (86756, u'abi')
# (40519, u'abm')
# (33500, u'abo')
# (13860, u'coroner')
# (40521, u'sarpeidon')
# (30415, u'abs')
# (86757, u'abt')
# (8587, u'abu')
# (19451, u'garth')
# (19452, u'judicious')
# (86758, u'aby')
# (3347, u'tribute')
# (86759, u"bedroom'")
# (18100, u'doting')
# (86760, u"'sunday")
# (51428, u'wrangling')
# (75835, u'negligee')
# (86761, u'macquire')
# (17142, u'abrasive')
# (25145, u'favourably')
# (40522, u'puddles')
# (25146, u'favourable')
# (8768, u'hanzo')
# (58285, u"healers'")
# (51429, u"ferdie's")
# (86763, u'dmd2222')
# (86764, u'arcaica')
# (86765, u'chipped')
# (86766, u'psalms')
# (86767, u'ont')
# (86768, u'storefront')
# (57478, u'zabar')
# (30416, u'chipper')
# (48156, u'copycats')
# (39129, u'cassevetes')
# (73029, u'tsuyako')
# (86770, u"regime's")
# (21839, u'roshan')
# (28274, u'deployment')
# (51431, u'deathmatch')
# (51432, u'jailbreak')
# (40523, u"chip's")
# (86771, u'acception')
# (21840, u'aptitude')
# (86772, u'huzzah')
# (40524, u'helmsman')
# (51433, u'nothings')
# (4986, u'distinct')
# (86774, u"'reality")
# (86775, u"ace's")
# (66767, u'widdecombe')
# (86776, u'wholesomely')
# (86777, u'abskani')
# (86778, u'torre')
# (86779, u'flagitious')
# (86780, u'megaphone')
# (86781, u'palillo')
# (86782, u"koenekamp's")
# (86783, u'caligola')
# (86784, u'scotia')
# (51434, u'ange')
# (40525, u"petersen's")
# (10775, u'staggering')
# (27509, u'reeked')
# (88310, u'pathologize')
# (27510, u'chimpanzee')
# (86785, u"'samurai")
# (51435, u'ikwydls')
# (86786, u'ungoriest')
# (86787, u'asheville')
# (86788, u'squeazy')
# (21841, u'coulardeau')
# (840, u'particular')
# (20546, u'staggers')
# (51436, u'finalization')
# (38750, u'farrellys')
# (86789, u'maerose')
# (86790, u'155')
# (86791, u'endingis')
# (78292, u'categorizing')
# (7909, u'taut')
# (86792, u"humphrey'")
# (86793, u"'intimacy'")
# (16087, u'sollett')
# (3307, u'shark')
# (25147, u'hamburger')
# (86794, u'unrevealing')
# (86795, u"fable's")
# (86796, u'shara')
# (86797, u'expeditiously')
# (30419, u'prods')
# (1494, u'share')
# (40526, u'shard')
# (86798, u"surya's")
# (34495, u'chimera')
# (51437, u"fidel's")
# (2452, u'sharp')
# (86799, u'askeys')
# (86800, u"daubeney'")
# (86801, u'prodd')
# (17592, u'concealed')
# (86802, u"lampidorra's")
# (34496, u'vosen')
# (34497, u'ryo')
# (13403, u'siren')
# (12590, u'csi')
# (51438, u'sired')
# (34498, u'rye')
# (86803, u'unredeeming')
# (51439, u'catskills')
# (58036, u'cst')
# (27511, u'ryu')
# (86804, u'rys')
# (86805, u'sires')
# (40527, u"claw's")
# (51440, u'dramatists')
# (40528, u'kinear')
# (30420, u'craptastic')
# (51441, u"gorshin's")
# (86806, u'knievel')
# (51442, u'familiarized')
# (3655, u'uninspired')
# (27512, u'polynesian')
# (23322, u'trois')
# (62860, u'proxate')
# (86808, u"cutters'")
# (14332, u'bathed')
# (21842, u'blandness')
# (86809, u"petron's")
# (86810, u'alicianne')
# (86811, u'cuhligyooluh')
# (30421, u'bathes')
# (86812, u'iene')
# (86813, u'masonite')
# (86814, u'lollos')
# (6533, u'chopped')
# (78413, u'igenious')
# (86815, u"schieder's")
# (86816, u'disengorges')
# (9079, u'muriel')
# (78421, u"'sensitivity'")
# (21843, u'borel')
# (86819, u"'goodies'")
# (4345, u'arrogant')
# (78433, u'lonestar')
# (30422, u'epos')
# (86821, u'arteries')
# (19453, u'possessions')
# (86822, u"aristocrat's")
# (86823, u'klusak')
# (18460, u'riget')
# (86824, u'vesica')
# (86825, u'crawly')
# (86826, u'riger')
# (60651, u'supposebly')
# (36787, u'roper')
# (68302, u'bharathi')
# (70101, u'stinkbug')
# (18396, u'crawls')
# (6699, u'arguments')
# (17593, u'lookout')
# (9865, u'goof')
# (86827, u'oks')
# (49, u'good')
# (30423, u'lucian')
# (78463, u'okw')
# (86829, u'sufice')
# (51450, u'gook')
# (16088, u'detour')
# (86831, u'oke')
# (86832, u'karaca')
# (30424, u'goop')
# (51451, u'declamatory')
# (40529, u'porto')
# (86833, u'mellifluousness')
# (86834, u'shittttttttttttttty')
# (10776, u'robbie')
# (2752, u'pregnant')
# (39180, u'porte')
# (86835, u'habousch')
# (86836, u"kershaw's")
# (40530, u'fadeout')
# (86837, u'clowned')
# (51452, u'ports')
# (86838, u'betweeners')
# (73001, u'\xa350')
# (86839, u'callum')
# (40531, u'marybeth')
# (18461, u'66')
# (86840, u'infernos')
# (84304, u'manvilles')
# (34501, u'sarducci')
# (51453, u'triffids')
# (78445, u'dan\xe7a')
# (27513, u'wiggling')
# (86841, u'furtherance')
# (27514, u'obtains')
# (86842, u'callup')
# (86843, u'callus')
# (6189, u'randolph')
# (2030, u'deals')
# (1843, u'lovers')
# (51454, u'creditor')
# (39190, u'effete')
# (86845, u'maritally')
# (86846, u'roughnecks')
# (71084, u'ok\x85')
# (86847, u"cady's")
# (86848, u'commode')
# (86849, u'podgy')
# (57391, u'\xa71000')
# (86850, u'ariete')
# (34502, u'duking')
# (86851, u"bandai's")
# (86852, u'ossana')
# (86853, u'offsets')
# (19223, u'bulls')
# (52656, u'cheekboned')
# (86855, u'terminals')
# (86857, u"'braveheart")
# (86858, u'dorset')
# (51456, u'brasiliano')
# (86859, u"theaters'")
# (40532, u'devilishly')
# (20589, u'underscored')
# (40533, u'divulges')
# (9080, u'prophet')
# (21844, u'blossoming')
# (86860, u"kumble's")
# (40534, u'cads')
# (20320, u'cady')
# (20547, u'disregarded')
# (86862, u"barretto's")
# (86863, u'cada')
# (51458, u'slithers')
# (86864, u'hathcock')
# (5972, u"viewer's")
# (16782, u'financing')
# (86866, u'visors')
# (30425, u"family'")
# (40535, u'loudmouths')
# (38719, u'elba')
# (40536, u'moles')
# (51459, u'cantaloupe')
# (4310, u'divorce')
# (11010, u'5th')
# (42269, u'colditz')
# (2587, u'statement')
# (51461, u'kakka')
# (86867, u'backwoodsman')
# (86868, u"horizon'")
# (34818, u'provocatively')
# (17594, u'uproarious')
# (27515, u'donaggio')
# (63695, u"jews'")
# (30426, u'newell')
# (86869, u"duk's")
# (25150, u'muscled')
# (34504, u'drunkenness')
# (86870, u'hooknose')
# (86871, u'qld')
# (86872, u"mature's")
# (34505, u'mclaughlin')
# (17595, u'horizons')
# (1837, u'gotten')
# (1937, u'youth')
# (86873, u'familys')
# (51462, u'kajlich')
# (40538, u"'rosemary's")
# (51463, u'macro')
# (86874, u"everlovin'")
# (57495, u'totter')
# (74135, u'family\x85')
# (9866, u'outta')
# (40539, u'agey')
# (86876, u"'trick")
# (34506, u'philippine')
# (27516, u'ager')
# (39213, u'dreamily')
# (30427, u'wyler')
# (73204, u"shaft's")
# (86878, u'gondek')
# (78743, u'agee')
# (27517, u'dismember')
# (14885, u'backseat')
# (2524, u'mountain')
# (86882, u'zanzeer')
# (40541, u"jon's")
# (1102, u'dancing')
# (23324, u'animatronic')
# (74140, u'family\xa8')
# (51464, u'documentry')
# (67745, u"hiasashi's")
# (40542, u'anthems')
# (57242, u'chemotrodes')
# (86884, u'jelled')
# (86885, u'crapping')
# (27518, u"jenny's")
# (57497, u'freekin')
# (13404, u'dalmatians')
# (40544, u'vibration')
# (30428, u'macchio')
# (34507, u'semra')
# (13136, u'jafar')
# (34508, u"age'")
# (86886, u'soldierly')
# (86887, u'engagements')
# (25151, u'chested')
# (51466, u'organist')
# (51467, u"dancin'")
# (51468, u"chester's")
# (86888, u"sommer's")
# (86889, u'incoherrent')
# (34509, u'organise')
# (11296, u'chester')
# (86890, u'nubo')
# (25218, u'palminteri')
# (34510, u'directness')
# (86891, u'nubb')
# (27519, u'organism')
# (12591, u'nobility')
# (16783, u'dodging')
# (86892, u"preity's")
# (86893, u"'brain")
# (17596, u'wailing')
# (43811, u'carny')
# (27520, u"farnsworth's")
# (51470, u'sop')
# (34511, u'womaniser')
# (86894, u'womanises')
# (4493, u'relation')
# (86895, u"wolfgang's")
# (30429, u'switchblade')
# (86896, u'carno')
# (51471, u"1934's")
# (86897, u'screenshots')
# (1587, u'faces')
# (1460, u'giant')
# (86898, u"'huge")
# (26137, u'holi')
# (18462, u'depended')
# (30430, u'dividing')
# (1061, u'waiting')
# (75629, u'\xabboy')
# (51472, u'chihiro')
# (86900, u'gutterballs')
# (86901, u'nkvd')
# (86902, u'nibelungos')
# (19454, u'villian')
# (86903, u'televangelism')
# (51473, u'paperweight')
# (40545, u'salaryman')
# (49060, u"lindy's")
# (40546, u'televangelist')
# (86904, u'blaznee')
# (86905, u'elapse')
# (16809, u'ammunition')
# (25152, u'redefines')
# (86906, u'rousch')
# (2131, u'bet')
# (40547, u'unenjoyable')
# (76564, u'retrouv\xe9')
# (86907, u'brooker')
# (21845, u'redefined')
# (16089, u'finlayson')
# (86908, u'brooked')
# (86909, u"company'ish")
# (86910, u"morales'")
# (21846, u"brendan's")
# (40549, u'dragstrip')
# (21847, u'wrongfully')
# (86911, u"'allergic")
# (11024, u'devils')
# (86912, u'printout')
# (2811, u'leslie')
# (51474, u"mendel's")
# (23325, u'surrendered')
# (86913, u'whitepages')
# (40517, u'carn\xe9')
# (86914, u'franciscans')
# (86915, u"lipton's")
# (51475, u'billingsley')
# (86916, u"bianlian's")
# (86917, u'tamales')
# (27521, u'binds')
# (86918, u'cobblepot')
# (86919, u"'viz'")
# (78961, u'donato')
# (83821, u'barbados')
# (86921, u'donath')
# (51476, u'donati')
# (86922, u'vaule')
# (40550, u'feasted')
# (17597, u'donate')
# (86923, u"albeniz'")
# (27522, u"brashear's")
# (86924, u'drury')
# (51045, u'genially')
# (27523, u"ri'chard")
# (51477, u'renews')
# (11908, u'vanishing')
# (34515, u"devil'")
# (86926, u'ourdays')
# (16784, u'lightness')
# (19236, u'alters')
# (40551, u'exhumed')
# (86928, u'ragdolls')
# (27524, u'larn')
# (34516, u'cubes')
# (86929, u'patheticness')
# (86930, u"them's")
# (10777, u'annual')
# (46327, u'thomerson\xb4s')
# (86931, u'mathias')
# (51911, u"busted's")
# (13359, u'boyd')
# (40552, u'spiritless')
# (86933, u'gielguld')
# (86934, u'awlright')
# (19455, u'consume')
# (73165, u'guested')
# (86936, u'sisson')
# (51478, u'cataloguing')
# (40553, u'bumblers')
# (86937, u'callipygian')
# (86938, u'sondergaard')
# (86939, u'alumnus')
# (34517, u'volunteered')
# (51479, u"'find'")
# (30431, u'scrapped')
# (51480, u'mejding')
# (86940, u"ruman's")
# (86941, u'raval')
# (25153, u'mikes')
# (12592, u'transformations')
# (25154, u'devouring')
# (2352, u'trilogy')
# (30432, u'mikey')
# (86943, u'thugee')
# (86944, u"'transformers'")
# (16785, u'collaborator')
# (72461, u'cast\xb4s')
# (40554, u"atlantic'")
# (86945, u'mikel')
# (59512, u'mispronunciation')
# (51482, u"'tower")
# (86946, u'yawnaroony')
# (86947, u'ratcatcher')
# (6534, u'cyborg')
# (39271, u'acolyte')
# (86949, u'treeline')
# (18464, u'nihilistic')
# (41864, u'sari\xf1ana')
# (30433, u'fending')
# (40555, u'nudists')
# (86950, u"'towed")
# (86951, u'rupture')
# (86952, u"serve'")
# (34518, u'arkush')
# (86953, u'mothra')
# (86954, u'claustraphobia')
# (27525, u'foreshadowed')
# (30434, u'towelhead')
# (86955, u'mikshelt')
# (86956, u'rigour')
# (34519, u'mortician')
# (86957, u"hrolfgar's")
# (86958, u'atlantica')
# (86959, u"dirt's")
# (70117, u'rationalistic')
# (40557, u'elucidation')
# (11025, u'embarks')
# (14246, u'moralistic')
# (20548, u'imperialist')
# (16786, u'drawbacks')
# (55481, u"he\x85it'll")
# (79121, u'230mph')
# (86961, u'maganac')
# (86963, u'ruppert')
# (86964, u'minutia')
# (51483, u'merrier')
# (86965, u'grecianized')
# (51484, u'unnoticeable')
# (86966, u'krecmer')
# (3166, u'italy')
# (88330, u'parroting')
# (40558, u'ewa')
# (51485, u'moviegoing')
# (30435, u"pressburger's")
# (86967, u'mysoginistic')
# (51486, u'ews')
# (3927, u'ruth')
# (40559, u'eww')
# (86968, u'powerlessness')
# (86969, u'genina')
# (4074, u'yesterday')
# (51487, u'solicited')
# (23326, u'flurry')
# (40560, u"'rush")
# (51488, u'unspools')
# (86970, u"'unsolved")
# (34521, u'maupassant')
# (14334, u'finesse')
# (59100, u'werewold')
# (86971, u'horsecocky')
# (1982, u'werewolf')
# (86972, u"'ludwig'")
# (86973, u'mordred')
# (51489, u'amisha')
# (25156, u'cheesier')
# (3195, u'entry')
# (7792, u'district')
# (88331, u'transportive')
# (51490, u'interweaves')
# (34523, u'sajani')
# (86974, u'hackdom')
# (27527, u"murray's")
# (51491, u'rabun')
# (23327, u'fundamentalists')
# (86975, u'upchucking')
# (4799, u'scrooge')
# (30436, u"'things")
# (51492, u'bi2')
# (39300, u'bi1')
# (51493, u'necromaniac')
# (86978, u"'less'")
# (27528, u'elfman')
# (51494, u'schnappmann')
# (19456, u"pixar's")
# (34525, u'wayland')
# (10080, u"streisand's")
# (86979, u'superfighters')
# (86980, u'funfare')
# (23328, u'sinise')
# (3976, u'bin')
# (8588, u'bio')
# (86981, u'bil')
# (86982, u'bim')
# (51495, u'bii')
# (191, u'big')
# (14335, u'bid')
# (86983, u'bie')
# (86984, u'bib')
# (51496, u"'thing'")
# (5741, u'redeem')
# (86985, u'maidservant')
# (14886, u'biz')
# (86986, u"drexler's")
# (51497, u'materialists')
# (86987, u'definently')
# (224, u'bit')
# (86988, u'bis')
# (86989, u'bip')
# (30437, u"jesus's")
# (86990, u"jafri's")
# (40562, u'blemish')
# (86991, u'xplosiv')
# (40563, u'merquise')
# (86992, u'bahal')
# (25157, u'expulsion')
# (40564, u'hessling')
# (86993, u'obscence')
# (12593, u'google')
# (86994, u'ckco')
# (397, u'often')
# (23329, u'extremism')
# (88335, u'coreys')
# (25158, u'abundantly')
# (86997, u'austreheim')
# (8024, u'underdeveloped')
# (25159, u'insincere')
# (2462, u'serves')
# (86998, u'ofter')
# (86999, u'malinski')
# (50176, u'multicolored')
# (3144, u'ourselves')
# (40565, u'googly')
# (9081, u'reruns')
# (34526, u'jitterbug')
# (40566, u'scala')
# (40567, u'defamation')
# (87000, u'escpecially')
# (9649, u'eliminate')
# (51500, u'scalp')
# (51501, u'bogdonovich')
# (87001, u"'alone")
# (79371, u"molnar's")
# (51502, u"deductible'")
# (87003, u"'external'")
# (75862, u'voluteer')
# (34527, u'costumer')
# (9867, u'virtues')
# (7551, u'blockbusters')
# (77167, u'shyt')
# (40568, u'lounges')
# (87005, u'acclimation')
# (16090, u'costumed')
# (49217, u'carbide')
# (87006, u"conroy's")
# (87007, u"metal's")
# (87008, u'thirsted')
# (65997, u"hair's")
# (51504, u'korty')
# (34528, u"babbage's")
# (40569, u'freakout')
# (450, u'drama')
# (23331, u'belting')
# (51505, u'korte')
# (87009, u'ghetoization')
# (87010, u'hungering')
# (87011, u'nuys')
# (79421, u'basting')
# (40571, u'buena')
# (51506, u'beatdown')
# (87013, u'bmob')
# (87014, u'bmoc')
# (87015, u"vanlint's")
# (87016, u'beejesus')
# (22508, u'subversion')
# (34529, u'proportional')
# (34530, u'xian')
# (4448, u'downhill')
# (7910, u'dafoe')
# (51507, u'kirsty')
# (12245, u'modicum')
# (84219, u'appropriating')
# (46357, u"'hood'")
# (30438, u'overpower')
# (87018, u"original'")
# (23332, u'pronunciation')
# (17598, u'broadcasts')
# (27530, u'handbook')
# (45942, u'southpark')
# (87019, u'erasmus')
# (21848, u'titan')
# (51508, u'sdp')
# (87020, u"'quality'")
# (33728, u'sleepers')
# (87021, u'abigil')
# (34531, u'serie')
# (52877, u'alcides')
# (62467, u"b'way")
# (30439, u'migrating')
# (87023, u'satchwell')
# (87024, u'calico')
# (87025, u'blanketing')
# (7175, u'originals')
# (25160, u'mavericks')
# (12150, u'hanna')
# (87027, u'obssession')
# (87028, u"tomorrow's")
# (87029, u'autonomous')
# (63249, u'lively\x85')
# (87031, u'georgette')
# (87032, u'playgroud')
# (63722, u'sociopathy')
# (87034, u"'rush'")
# (88342, u'epiphanal')
# (8053, u'dragging')
# (20551, u'essayed')
# (87035, u'transmutes')
# (87036, u'streamlining')
# (40573, u'humanities')
# (87037, u'tactlessness')
# (51511, u'transmuted')
# (40574, u"ahab's")
# (87038, u"anbuselvan's")
# (87039, u'pesticides')
# (8054, u'inclined')
# (30447, u'incidences')
# (51512, u"'haunted")
# (1637, u'favourite')
# (51514, u'trombones')
# (87041, u'knarl')
# (15478, u'papa')
# (34532, u'druid')
# (29465, u'oedipus')
# (87042, u'papp')
# (87043, u'paps')
# (87044, u'blinky')
# (87045, u'volney')
# (34533, u'blinks')
# (34534, u'wolske')
# (87046, u'tradeoff')
# (87047, u"nunez'writing")
# (79624, u'wolsky')
# (87049, u"sinise's")
# (87050, u'rinse')
# (87051, u'aguilera')
# (88535, u'ending\x97in')
# (84676, u'lisps')
# (87053, u'grogan')
# (33564, u'pulsing')
# (6619, u'intricate')
# (87055, u'westwood')
# (23333, u'eggert')
# (51515, u'superlame')
# (73639, u'other\x85')
# (34535, u'breached')
# (24187, u'giddily')
# (40575, u'lilli')
# (44458, u'lillo')
# (13405, u'mower')
# (16788, u'intensive')
# (25161, u'glaser')
# (21849, u'blaze')
# (33707, u'mowed')
# (87057, u'prival')
# (11531, u'lilly')
# (87059, u'afros')
# (14336, u'brigade')
# (40576, u'koteas')
# (34536, u'electrocute')
# (17303, u'auer')
# (87061, u'maiga')
# (30441, u'velankar')
# (87062, u'kaneshiro')
# (36015, u"video'")
# (68513, u'bettering')
# (35693, u'infrared')
# (34537, u'clement')
# (87064, u'spiritualized')
# (51517, u'understandings')
# (87065, u'profligacy')
# (16091, u'uncovering')
# (21850, u'populist')
# (51518, u"'wicked")
# (40577, u'shenzi')
# (87066, u'nikos')
# (51519, u'gawdawful')
# (75876, u'madeira')
# (51520, u'mwah')
# (23334, u'redd')
# (14337, u'vistas')
# (87067, u"other'")
# (13861, u'uncomfortably')
# (87068, u'grooved')
# (87069, u'replicates')
# (51521, u"whoopi's")
# (3145, u'uncomfortable')
# (40578, u'replicated')
# (88346, u'matelot')
# (87072, u'supervillian')
# (3491, u'depression')
# (12246, u'reconciliation')
# (34538, u'ruka')
# (25162, u'estonian')
# (87073, u"'issues'")
# (87074, u'procurator')
# (51522, u'falcons')
# (5673, u'rukh')
# (51523, u'condominium')
# (87075, u"zizola's")
# (27532, u'manservant')
# (48168, u'blotting')
# (40579, u'falcone')
# (87077, u'chasers')
# (87078, u'appereantly')
# (34539, u'50th')
# (27533, u'kader')
# (7793, u'sins')
# (87079, u"groove'")
# (87080, u'timberflake')
# (87081, u'sinn')
# (87082, u'sino')
# (43991, u'gamecube')
# (23963, u'dictators')
# (51524, u'miasma')
# (406, u'others')
# (30442, u'dissuade')
# (57529, u'tadeu')
# (51525, u'sine')
# (2224, u'irritating')
# (30443, u'widening')
# (51526, u'masatoshi')
# (87083, u'relaesed')
# (88349, u'thepace')
# (51527, u'bolls')
# (11576, u'contradiction')
# (87085, u'bollo')
# (87086, u'cavils')
# (3167, u'proof')
# (87087, u"fiance's")
# (87088, u"falcon'")
# (87089, u'bolla')
# (87090, u'annabeth')
# (87091, u'cabarnet')
# (82612, u'feffer')
# (18467, u'talos')
# (51528, u'talor')
# (34540, u'towners')
# (87092, u'talon')
# (51529, u'egress')
# (87093, u'signposting')
# (87094, u'multitask')
# (30226, u'presidente')
# (51531, u'impotency')
# (51532, u'sacchi')
# (39415, u"'style'")
# (51533, u'toshio')
# (14887, u'breakup')
# (51534, u'beefed')
# (87095, u'felsh')
# (87096, u'incarcerations')
# (51535, u'aformentioned')
# (25164, u'impotence')
# (40580, u'humbleness')
# (87097, u'allyce')
# (6620, u'tax')
# (87098, u'getters')
# (87099, u'biller')
# (87100, u'astoria')
# (51536, u'malte')
# (9253, u'payne')
# (51537, u'emigration')
# (87101, u'hailstorm')
# (40581, u'magnanimous')
# (87102, u'debtors')
# (87103, u'procuring')
# (87104, u"thomp's")
# (87105, u'gagoola')
# (40582, u'inclinations')
# (87106, u'synonamess')
# (88354, u'kyer')
# (6102, u'tunnel')
# (40584, u'hyperkinetic')
# (87107, u'peregrinations')
# (40585, u'exhilaration')
# (19459, u'heaving')
# (40586, u'crickets')
# (39928, u'turntable')
# (87108, u'tunney')
# (87109, u'unpacking')
# (30445, u'turhan')
# (87110, u'kehna')
# (63736, u'polchek')
# (23335, u'sandino')
# (87111, u'gimbli')
# (87112, u'therin')
# (87113, u"bruckheimer's")
# (6621, u'scarface')
# (51538, u'reanimates')
# (20591, u'tam')
# (70145, u'rapa')
# (87114, u"'snappy'")
# (51539, u'gci')
# (51922, u'onions')
# (87116, u'marjoke')
# (87117, u'dionysian')
# (51540, u'thrall')
# (87118, u'vieller')
# (87119, u'abunch')
# (51541, u'meditated')
# (33748, u'rousseau')
# (51542, u'licitates')
# (51543, u'bombardiers')
# (51544, u"amos's")
# (11795, u'dc')
# (40587, u"jill's")
# (40588, u'yielded')
# (51545, u'milos')
# (87120, u'korie')
# (87121, u"'synth'")
# (87122, u'bugaloos')
# (87123, u'phantasmal')
# (87124, u'sententious')
# (87125, u'loisaida')
# (87126, u'gudalcanal')
# (87127, u'bomberg')
# (66690, u'naturism')
# (25206, u"montana's")
# (81153, u"duprez's")
# (23336, u'coordinated')
# (27534, u'languorous')
# (51546, u'repentant')
# (87128, u"'unintentional'")
# (13406, u'shreds')
# (72971, u"wow'")
# (11910, u'austrian')
# (87129, u'screwiest')
# (87130, u'futz')
# (5973, u'bridges')
# (87131, u'negotiated')
# (7431, u'du')
# (5556, u'bridget')
# (87132, u'nabooboo')
# (21851, u'relativity')
# (51548, u"rogers's")
# (87133, u'ocars')
# (44399, u'honks')
# (34542, u'squatting')
# (87135, u'negotiates')
# (51549, u'bridged')
# (87136, u'hardbitten')
# (87137, u"'hostel'")
# (51550, u'intrested')
# (1243, u'dad')
# (87138, u"binoche's")
# (51551, u'serra')
# (7469, u'lunatic')
# (87139, u'dobbed')
# (87140, u'divagations')
# (10778, u'dam')
# (2127, u'dan')
# (87141, u'dao')
# (73174, u'wows')
# (87142, u'rissole')
# (8660, u'blessed')
# (30449, u'dat')
# (31924, u'dau')
# (51552, u'daw')
# (87144, u'sonata')
# (15479, u'das')
# (20552, u'dax')
# (248, u'day')
# (25165, u'serpentine')
# (30450, u'earle')
# (51553, u'wisbar')
# (87145, u"viewpoint's")
# (2812, u'warned')
# (12247, u'radiant')
# (87146, u'slacked')
# (40589, u'osmond')
# (87147, u"giants'")
# (87148, u'25mins')
# (51554, u'toke')
# (87149, u'peschi')
# (63746, u"'tries")
# (17600, u'slacker')
# (87150, u"linney's")
# (87151, u'warnes')
# (2988, u'warner')
# (51555, u'activate')
# (87152, u'ziegfield')
# (87153, u'hitgirl')
# (87154, u"allan's")
# (7911, u'dreaming')
# (88469, u"kylie's")
# (34543, u'administrator')
# (87155, u"gifford's")
# (23806, u'exodus')
# (87156, u'calibrate')
# (30451, u'slumped')
# (77709, u"google'd")
# (58794, u'messege')
# (51556, u'blesses')
# (40590, u'byplay')
# (87157, u'jampacked')
# (87158, u'extinguishing')
# (87159, u'extricates')
# (87160, u'waas')
# (40591, u'bullfighter')
# (25166, u'arkansas')
# (70150, u'bestsellers')
# (51557, u'waay')
# (19460, u'wincing')
# (87162, u'coolish')
# (5791, u'harold')
# (9082, u'christensen')
# (10268, u'blackie')
# (87163, u'controlness')
# (87164, u'motherlode')
# (87165, u'dewames')
# (87166, u'gouched')
# (17601, u'acre')
# (20553, u'squadron')
# (40593, u'turbans')
# (87167, u"sarsgaard's")
# (27536, u'bowman')
# (40594, u'peeve')
# (88364, u'perjury')
# (87169, u'mourir')
# (87170, u"marber's")
# (8282, u'dreyfuss')
# (87171, u'seon')
# (23337, u'sorrowful')
# (87172, u'storyboards')
# (21852, u'reconciled')
# (30453, u'madden')
# (51559, u'bleeps')
# (87173, u'desireless')
# (5073, u'puppet')
# (11911, u'raggedy')
# (40595, u'pauper')
# (39478, u'sassiness')
# (51560, u'commendations')
# (18468, u'expressionistic')
# (16790, u"love'")
# (1035, u'sadly')
# (40596, u'madder')
# (51561, u'laps')
# (4379, u'chased')
# (34544, u'establishments')
# (12594, u'kazaam')
# (51562, u'immovable')
# (40244, u'distractingly')
# (20554, u'palestine')
# (51563, u'chaser')
# (34545, u'ferocity')
# (51564, u'natty')
# (5742, u'gear')
# (12986, u'unscrupulous')
# (87175, u'udy')
# (87176, u"'hiccups'")
# (40597, u'forethought')
# (20555, u'unending')
# (87177, u"lar'")
# (87178, u'prominance')
# (20556, u'udo')
# (87179, u'stumping')
# (444, u'loved')
# (5840, u'glamorous')
# (34546, u'kochak')
# (51565, u'spookiest')
# (51566, u'lim')
# (18469, u'compensation')
# (87180, u'halcyon')
# (51567, u'plexiglass')
# (1458, u'lover')
# (87181, u'parati')
# (8165, u'pretends')
# (34547, u'lovey')
# (87182, u'woche')
# (87183, u'eventless')
# (51568, u"sis'")
# (39491, u'replicant')
# (39492, u'seville')
# (51569, u'miyan')
# (87185, u'terribles')
# (20557, u'hingle')
# (14810, u'purgatory')
# (17602, u'dementia')
# (10544, u'demonstration')
# (87187, u"'madam")
# (27537, u'sayings')
# (23338, u'minimally')
# (7794, u'dallas')
# (51570, u'masochistically')
# (87188, u'newgate')
# (70161, u'hippiest')
# (87189, u"baccalieri's")
# (51571, u'loups')
# (87190, u'sequentially')
# (51572, u'chaise')
# (87191, u"eaters'")
# (18470, u'rediscovered')
# (87192, u"terrible'")
# (87193, u"business'")
# (87194, u'sisk')
# (80439, u'trundles')
# (87195, u'truces')
# (87196, u"'robin")
# (75032, u'\xa3300')
# (80456, u'ruffianly')
# (3492, u'sophisticated')
# (51573, u'reveling')
# (7362, u'herman')
# (87198, u"linden's")
# (87199, u'gullet')
# (13863, u'allegorical')
# (30454, u'hostesses')
# (5228, u'gather')
# (87200, u'svenon')
# (87201, u'capita')
# (87202, u'gulled')
# (81895, u'purgatori')
# (20558, u'batgirl')
# (87203, u'whateverness')
# (80500, u"movied'")
# (87204, u'shooked')
# (5557, u'selection')
# (21853, u'kite')
# (87205, u'urineing')
# (3001, u'text')
# (25167, u'humanizing')
# (81285, u'rereleased')
# (87206, u'dilwale')
# (21854, u'kitt')
# (70269, u"\x91movie'")
# (34549, u'portfolio')
# (87207, u'spitied')
# (51574, u'texa')
# (13416, u'elia')
# (34550, u"1937's")
# (87208, u"calvet's")
# (40600, u'reversion')
# (16791, u'contradictory')
# (87209, u'scuttling')
# (87210, u'yeshua')
# (51575, u'gayatri')
# (87211, u"'mechanical")
# (87212, u"villarona's")
# (6190, u'photographs')
# (7089, u'laputa')
# (40601, u'thouroughly')
# (3157, u'exceptional')
# (1378, u'photography')
# (29027, u"aniston's")
# (87215, u'striper')
# (17603, u'distinguishes')
# (51576, u'enunciating')
# (51577, u'hifi')
# (87216, u'rekka')
# (25168, u'occupant')
# (30455, u'deputies')
# (45531, u'tutazema')
# (40602, u'striped')
# (51578, u'jiving')
# (87219, u"clarity's")
# (30456, u'natascha')
# (87220, u'vandebrouck')
# (2780, u'calling')
# (87221, u'englishness')
# (87222, u'buchinsky')
# (87224, u'ballplayers')
# (51579, u'100min')
# (13947, u'camaraderie')
# (30457, u"'zavet'")
# (51580, u"scenery's")
# (87226, u'infidel')
# (87227, u"sheritt's")
# (87228, u'outfielder')
# (51581, u'dislodge')
# (34551, u'jaques')
# (40603, u'trekovsky')
# (27538, u'phases')
# (33884, u'turks')
# (25169, u'wastrel')
# (23339, u'clearing')
# (51582, u'motown')
# (30458, u'nebula')
# (87232, u'gentlemanlike')
# (7090, u"branagh's")
# (87233, u"'nanites'")
# (13407, u'rowan')
# (49588, u'phased')
# (87234, u'derisively')
# (2496, u'routine')
# (87235, u"plimton's")
# (51583, u'qayamat')
# (87236, u"shar'ia")
# (87237, u'bloomsday')
# (80673, u'vrs')
# (51584, u'nudged')
# (87238, u"o'herlihy's")
# (87239, u'unninja')
# (88372, u'encyclicals')
# (63764, u"faces'")
# (65571, u"'eureka")
# (51585, u"fujiko's")
# (30460, u'nudges')
# (31913, u'conqueror')
# (42514, u'neurotics')
# (87242, u'selena')
# (87243, u'mitevska')
# (16792, u'sexed')
# (39495, u'whelan')
# (19461, u'foibles')
# (87244, u'embryos')
# (87245, u'moderators')
# (10545, u'sexes')
# (40604, u"'mojo'")
# (87246, u'broson')
# (897, u'otherwise')
# (87247, u"'rip")
# (87875, u'set\x85')
# (51586, u'invasive')
# (34553, u'fostering')
# (29579, u'predicable')
# (87250, u'riffles')
# (34674, u'antonius')
# (34554, u"flicks'")
# (9868, u'monstrosity')
# (87253, u'saviors')
# (51587, u'technologist')
# (87254, u'oskorblyonnye')
# (70170, u'sarlac')
# (3536, u'tremendous')
# (87256, u'actualize')
# (87257, u"nunez'")
# (40605, u"basket's")
# (5169, u'darren')
# (20559, u'warwick')
# (8055, u'upbeat')
# (51588, u'gigolos')
# (6768, u'define')
# (51589, u"desdemona's")
# (87259, u'469')
# (87260, u'465')
# (14944, u'permeates')
# (34555, u'zealander')
# (40606, u'fantasyland')
# (87261, u"chruch's")
# (828, u'general')
# (87262, u'oshea')
# (40607, u'plaid')
# (1041, u'plain')
# (16793, u'promoter')
# (51590, u'rectangular')
# (40608, u'blasco')
# (34556, u"neo's")
# (87264, u"'white'")
# (86114, u'unflavored')
# (87265, u'determinism')
# (51591, u'transitioned')
# (87266, u'antirust')
# (87267, u'cereals')
# (9839, u'planets')
# (15481, u'helper')
# (23340, u"liotta's")
# (87268, u'claimer')
# (21856, u'berates')
# (1675, u'helped')
# (87269, u'landfills')
# (40609, u'tampered')
# (40610, u'aggressiveness')
# (51592, u'berated')
# (2989, u'inspector')
# (87270, u'lecouvreur')
# (30461, u'watchful')
# (87271, u"set'")
# (40611, u'desilva')
# (40612, u'eliot')
# (9451, u'administration')
# (87272, u'untypically')
# (30462, u"petiot's")
# (51593, u'anorak')
# (87273, u'authorty')
# (51594, u"'bonjour")
# (2230, u'fill')
# (51595, u'clubbed')
# (27540, u'blooms')
# (75905, u'parries')
# (87274, u'huckaboring')
# (87275, u'22101')
# (30464, u'tighten')
# (88377, u'yazaki')
# (33246, u'cog')
# (6786, u'samantha')
# (87277, u'cof')
# (87278, u'whiile')
# (40613, u'ion')
# (34557, u'injures')
# (87279, u'ioc')
# (87280, u'airlock')
# (70173, u"'hitler")
# (10081, u'raping')
# (87282, u'seto')
# (7912, u'seth')
# (34558, u'seti')
# (80915, u'kempo')
# (23892, u'interpol')
# (2717, u'position')
# (2694, u'con')
# (87284, u'stoogephiles')
# (71484, u'amritlal')
# (87285, u'alki')
# (40614, u'arming')
# (87286, u'intransigence')
# (51596, u"thomson's")
# (30465, u"roberts'")
# (3512, u'executive')
# (87287, u'evince')
# (23341, u'voltage')
# (87288, u'hideos')
# (30466, u'twerp')
# (70176, u"'breakfast'")
# (87291, u'kampf')
# (87292, u'frownbuster')
# (27541, u'absorption')
# (12595, u'terrorized')
# (2141, u'lake')
# (51597, u'underact')
# (51598, u'mismarketed')
# (87294, u'gegen')
# (87295, u"'trancers'")
# (87296, u'kennyhotz')
# (4673, u'niro')
# (9254, u'crass')
# (87297, u'terrorizer')
# (34559, u'terrorizes')
# (87298, u'itelf')
# (87299, u'shitters')
# (11123, u'kali')
# (87300, u"90s'")
# (51599, u'fye')
# (23342, u'fyi')
# (87301, u'fym')
# (68404, u"camper's")
# (87304, u'newsstand')
# (14338, u'royalty')
# (51600, u"heisenberg's")
# (87305, u'hotbod')
# (70180, u"ifans'")
# (87307, u'rettig')
# (30467, u'audibly')
# (40616, u'heep')
# (87308, u'diehards')
# (51601, u'standoffish')
# (11027, u'inviting')
# (87309, u'guin')
# (19463, u'sofa')
# (51602, u'qualitative')
# (87310, u'leathermen')
# (70181, u'opaeras')
# (87312, u'kuala')
# (13081, u'heed')
# (87314, u"'boy'")
# (1793, u'soft')
# (16092, u'audible')
# (13864, u'heel')
# (87316, u'tawana')
# (87317, u'fying')
# (34560, u'eased')
# (87318, u'1982s')
# (87319, u'abolitionism')
# (51603, u'swimsuits')
# (78901, u'kid\u2019s')
# (25172, u'nanavati')
# (24861, u'stuffs')
# (87320, u'retentively')
# (13865, u'stuffy')
# (40617, u'kiberlain')
# (61707, u'regenerative')
# (15482, u'highlighting')
# (87321, u'patridge')
# (3583, u'corpse')
# (54265, u'campeones')
# (18505, u'fiddle')
# (9650, u'chains')
# (88385, u'brontosaurus')
# (9651, u'regain')
# (51604, u'plumped')
# (14800, u'hose')
# (87323, u'rumpy')
# (70183, u'mollifies')
# (51605, u'gynoid')
# (29984, u'geisel')
# (40618, u'nastie')
# (3229, u'host')
# (87326, u'expire')
# (81097, u'mockmuntaries')
# (87327, u"hurts'")
# (34562, u'whacks')
# (40619, u'christened')
# (30468, u'beaker')
# (87328, u"tagge's")
# (34563, u'bhamra')
# (87329, u'6am')
# (30554, u'tray')
# (30469, u'albanian')
# (40620, u'stephenson')
# (3153, u'hint')
# (40622, u'horrorvision')
# (87330, u'arrggghhh')
# (51608, u'scums')
# (87331, u"usage's")
# (21857, u'conway')
# (87332, u'torpedos')
# (11912, u'zooms')
# (82977, u'astrotheology')
# (16094, u'chronic')
# (87333, u"'slags'")
# (87334, u'bohumil')
# (87335, u'guerdjou')
# (87336, u'charleze')
# (87337, u"poeshn's")
# (19465, u'nandini')
# (21858, u'vampirism')
# (51609, u'titilation')
# (51610, u'howland')
# (87338, u'adversarial')
# (8166, u'awarded')
# (3248, u'burning')
# (11913, u'applegate')
# (21859, u'utopian')
# (11914, u'maze')
# (87339, u'haddofield')
# (34564, u'relishing')
# (10779, u'ivory')
# (23343, u'enchantment')
# (87340, u'brang')
# (3431, u'brand')
# (34565, u'caitlin')
# (1788, u'reminds')
# (87341, u'mattolini')
# (87342, u'amita')
# (87343, u'kobayaski')
# (87345, u'shihomi')
# (11298, u'lynn')
# (1821, u'dangerous')
# (87347, u'lyne')
# (1465, u'j')
# (613, u'annoying')
# (21860, u'backfires')
# (87348, u"'detailed")
# (88391, u'siana')
# (51611, u'doorknobs')
# (51612, u'lynx')
# (87349, u'372')
# (40624, u'backfired')
# (51613, u'preyed')
# (27543, u'plutonium')
# (82128, u'ones\x97with')
# (87350, u"'nightmarish'")
# (39762, u'sebastain')
# (23344, u'firepower')
# (40625, u"red's")
# (2453, u'deaths')
# (51615, u'destabilise')
# (88393, u"'masked")
# (87352, u'amphetamine')
# (87353, u'deathy')
# (87354, u'lembeck')
# (12987, u'crusade')
# (87356, u'tabletop')
# (87357, u'speelman')
# (1202, u'shooting')
# (87358, u'misstated')
# (13866, u'unintelligible')
# (23345, u'latch')
# (87359, u'aquariums')
# (12988, u'patsy')
# (2424, u'surreal')
# (11577, u'sewer')
# (18471, u'headmistress')
# (40626, u'spivs')
# (40627, u'picchu')
# (87360, u'meaneys')
# (58599, u'vfc')
# (87361, u'handcrafted')
# (88394, u"'smallpox")
# (87363, u"wilton's")
# (55011, u'prematurely\x85leaving')
# (87364, u'insupportable')
# (87365, u"imm's")
# (87366, u'shouldve')
# (51617, u'enlargement')
# (23346, u"death'")
# (87367, u'austrialian')
# (87368, u'misgauged')
# (87369, u"'doom")
# (51618, u'astronomy')
# (87370, u'malcomx')
# (20561, u'philips')
# (87371, u'runyonesque')
# (87372, u'philipp')
# (27544, u"'old'")
# (34566, u'yelp')
# (51619, u'bulwark')
# (81924, u'squirmers')
# (30470, u'philipe')
# (7796, u'yell')
# (87374, u'thunderstorms')
# (10546, u'8th')
# (16794, u'yentl')
# (87376, u'burdening')
# (87377, u"parnell's")
# (27545, u'assembles')
# (87378, u'streisandy')
# (18472, u'sleek')
# (27546, u'earmarks')
# (1663, u'sleep')
# (87379, u'51st')
# (40629, u'manfredi')
# (6535, u'assembled')
# (87380, u'carolinas')
# (87381, u'upchuck')
# (5792, u'feeding')
# (1447, u'paris')
# (87382, u'egomaniacal')
# (76006, u'\x96conservative')
# (51620, u'lanford')
# (87383, u'vicissitude')
# (49984, u'vili')
# (40630, u'neul')
# (9083, u'lure')
# (87384, u'zhestokij')
# (49826, u'incurs')
# (23347, u'lurk')
# (40631, u'amorphous')
# (87385, u'letzter')
# (87386, u'lololol')
# (87388, u'levelling')
# (11578, u'fireplace')
# (7470, u'parrot')
# (87390, u'cremating')
# (14888, u'venue')
# (87391, u"cusak's")
# (20562, u"'classic'")
# (67136, u'admissible')
# (87393, u'enclosing')
# (54949, u"angle's")
# (40632, u'rohinton')
# (15483, u'venus')
# (87395, u'bimbettes')
# (51621, u'methane')
# (81428, u'talen')
# (19466, u'infancy')
# (87396, u'razed')
# (87397, u'scrutinize')
# (51622, u'borrowings')
# (49851, u'seafront')
# (9869, u'ideology')
# (81475, u'razer')
# (51623, u'bethune')
# (40023, u'zinn')
# (87398, u'schedulers')
# (2887, u'christ')
# (78199, u'guy\x96his')
# (87399, u'elixirs')
# (66530, u'observantly')
# (87401, u'profitability')
# (87402, u'sulphurous')
# (87403, u'zink')
# (65161, u'crawford\u2019s')
# (19854, u'duplicated')
# (87404, u"'introduced'")
# (4843, u'seeks')
# (81513, u'lodi')
# (87406, u"boromir's")
# (40633, u'lode')
# (87409, u'lodz')
# (87410, u'thirtyish')
# (87411, u"'dialect'")
# (87412, u'mikeandvicki')
# (87413, u"'production")
# (87414, u'digits')
# (87415, u"nicalo's")
# (18749, u'tsai')
# (40634, u'kleist')
# (39683, u'bloomed')
# (87417, u"seek'")
# (1191, u'changed')
# (27547, u'donning')
# (23348, u"chris'")
# (51625, u'federline')
# (3263, u'hunting')
# (1440, u'changes')
# (34570, u'changer')
# (23349, u'unglamorous')
# (51626, u'blowtorch')
# (87418, u'sonnie')
# (51627, u'contributers')
# (40635, u'implode')
# (30471, u'iconoclast')
# (34571, u"'fido'")
# (20563, u'forums')
# (40636, u'heathrow')
# (25174, u'yore')
# (31232, u"spy'")
# (30473, u'idyll')
# (61580, u'logician')
# (39696, u"alda's")
# (51629, u'spellbounding')
# (87419, u'discourses')
# (42678, u'espisode')
# (51630, u'racketeer')
# (8283, u'asset')
# (2123, u'creates')
# (8923, u'slaughtered')
# (17604, u'mush')
# (14416, u'alberto')
# (87421, u'vangard')
# (87422, u'ensnared')
# (40637, u'musa')
# (87423, u"'town'")
# (88399, u'dormitories')
# (14339, u'muse')
# (40638, u'freccia')
# (34573, u'pinching')
# (87425, u'muss')
# (87426, u'offfice')
# (33937, u'trevethyn')
# (25176, u'mehbooba')
# (40639, u'tampa')
# (212, u'must')
# (58215, u'mombi')
# (25927, u'hesitated')
# (16095, u'henri')
# (63784, u"bozo's")
# (81661, u'spyl')
# (23351, u'foils')
# (81665, u'hypermarket')
# (87431, u'graceland')
# (1466, u'henry')
# (81673, u"caligula's")
# (30474, u"gabriel's")
# (87433, u'watertight')
# (87434, u'chilcot')
# (40641, u"muriel's")
# (87435, u'tuggee')
# (40642, u'magnificient')
# (23352, u'corsia')
# (23625, u'scheduling')
# (34574, u'oppressing')
# (51631, u'buna')
# (27548, u'bunk')
# (51632, u'debunkers')
# (30475, u'intruders')
# (87438, u'grammatically')
# (70210, u'feasibly')
# (21861, u'adjacent')
# (30476, u'infamously')
# (87440, u'swiftness')
# (87441, u'jabberwocky')
# (27549, u'patting')
# (51633, u"minorities'")
# (40643, u'esthetically')
# (87442, u'tetsukichi')
# (87443, u'livington')
# (51634, u'laughting')
# (51635, u'predicated')
# (87444, u'whittle')
# (40644, u'preconception')
# (51636, u'mouthpieces')
# (87445, u'rummy')
# (87446, u'scareless')
# (1735, u'danny')
# (30477, u'balk')
# (8769, u'hypnotic')
# (87448, u'hypotheses')
# (9625, u'allison')
# (17605, u'danni')
# (40645, u'northfield')
# (87449, u"munk's")
# (30478, u'fillers')
# (87450, u'reaks')
# (87451, u'namak')
# (27188, u'anouska')
# (30040, u'castel')
# (87453, u'sanitory')
# (8418, u'casted')
# (6431, u'expects')
# (40647, u'jacuzzi')
# (13408, u'carnal')
# (51637, u'caster')
# (15484, u'talkative')
# (10547, u'digest')
# (87454, u'crocteasing')
# (7471, u'edith')
# (30479, u'mongolia')
# (484, u'writing')
# (9870, u'edits')
# (69281, u'mechapiloting')
# (87455, u'noemi')
# (16096, u'stifling')
# (27551, u'wauters')
# (87456, u"'hulk'")
# (87457, u'carolingian')
# (87458, u"rawhide's")
# (87459, u'beggining')
# (51639, u'tantalizes')
# (16596, u'plates')
# (18473, u'chronology')
# (51640, u'credential')
# (87461, u'preventable')
# (30480, u'obligingly')
# (20565, u"grey's")
# (14340, u'dictatorship')
# (51642, u"donnersmarck's")
# (7748, u'explode')
# (87463, u'ahahhahahaha')
# (87464, u'kappor')
# (87465, u"'everybody's")
# (51643, u'dethrone')
# (17606, u'stressful')
# (40648, u'constipation')
# (4396, u'diana')
# (21026, u'hesseman')
# (20167, u"elliott's")
# (4286, u'diane')
# (9871, u'celebrating')
# (22814, u'adeptly')
# (88412, u'vampress')
# (51645, u'dispiriting')
# (87468, u'sexshooter')
# (87469, u'shootist')
# (27552, u'uncharismatic')
# (21862, u'reused')
# (65583, u'hoberman')
# (1950, u'driving')
# (63792, u'kiowa')
# (51646, u'emphysema')
# (87471, u'kazushi')
# (87472, u'mayday')
# (88508, u'15\x96year')
# (69812, u'resistor')
# (63591, u"'missing'")
# (9452, u'arizona')
# (51647, u'hemorrhaging')
# (87474, u'bogdonavitch')
# (87475, u'barmaids')
# (87476, u'srtikes')
# (1799, u'fred')
# (27553, u'whereupon')
# (442, u'evil')
# (87477, u"'happens'")
# (87478, u'freq')
# (40650, u'superimpose')
# (87479, u'westside')
# (51648, u"dorff's")
# (40651, u'fret')
# (87480, u'tillier')
# (40652, u'anthropomorphic')
# (87481, u"drivin'")
# (87482, u'mudbank')
# (60482, u'biltmore')
# (51649, u'clandestinely')
# (34575, u'renying')
# (11028, u'overused')
# (40653, u'corrections')
# (30481, u'inspectors')
# (73010, u"edge''")
# (11915, u'narratives')
# ...
# (88283, u"philadelphia'")
# (7432, u'entrance')
# (51897, u"board's")
# (27614, u'ether')
# (88284, u'actores')
# (88285, u"jawab'")
# (14894, u'anamorphic')
# (88286, u'haney')
# (88538, u'sequency')
# (40497, u"hay's")
# (73619, u'svengoolie')
# (49510, u'blankfield')
# (88290, u'wg')
# (88291, u'supblot')
# (36715, u'intercedes')
# (88293, u"turaquistan's")
# (13419, u'leaden')
# (27615, u'primetime')
# (7691, u'understatement')
# (82051, u'amrapurkars')
# (88295, u'sheryll')
# (51898, u'92nd')
# (88296, u'inflame')
# (30371, u'sideline')
# (51410, u'digressive')
# (88298, u'dimeco')
# (77331, u'dead\x97only')
# (88299, u'appalingly')
# (51899, u'delineation')
# (40766, u"2004's")
# (51900, u"shining'")
# (72, u'we')
# (40767, u'reproaches')
# (40768, u'lafayette')
# (88301, u'diamiter')
# (88302, u'moveis')
# (14352, u'mardi')
# (11583, u"wells'")
# (88303, u'850pm')
# (30543, u'lacanian')
# (40769, u'redlitch')
# (21894, u'sadistically')
# (6928, u'lean')
# (88304, u'jacqualine')
# (76616, u'saxophonists')
# (88306, u'disey')
# (11923, u'contributions')
# (51901, u'magnifying')
# (59238, u"nau'ers")
# (34665, u'liberators')
# (88307, u'showthread')
# (88308, u'someincredibly')
# (40770, u'whig')
# (34666, u'fenced')
# (11520, u'celie')
# (40771, u"'hot'")
# (16480, u'celia')
# (40772, u'visualizing')
# (25217, u'hinduism')
# (88311, u'trasforms')
# (18500, u'fences')
# (34667, u'fencer')
# (7574, u'snipes')
# (6434, u'sniper')
# (30544, u'abode')
# (4463, u'wished')
# (88313, u"'moviefreak'")
# (2216, u'lynch')
# (30545, u'bedrooms')
# (30546, u'713')
# (88314, u'honost')
# (51443, u'slickest')
# (24163, u'alden')
# (3082, u'wishes')
# (51904, u'spectaculars')
# (88316, u'harlot')
# (7179, u'harlow')
# (88317, u"o'd")
# (3625, u'notes')
# (15491, u'underscores')
# (20588, u'murdoch')
# (51905, u'minimizing')
# (18501, u'outdo')
# (9350, u'astronaut')
# (35075, u'silberman')
# (3209, u'noted')
# (51906, u'untraditional')
# (30547, u'procession')
# (63906, u'bodybuilding')
# (34668, u"y'know")
# (51907, u"serat's")
# (51908, u'rrw')
# (12995, u'manipulating')
# (34669, u'fermenting')
# (88319, u'cronicles')
# (88320, u'stth')
# (66357, u'unber\xfchrbare')
# (88321, u'page2')
# (88322, u"foywonder's")
# (8057, u'networks')
# (31285, u'16\xe8me')
# (51909, u'augie')
# (27617, u'relocate')
# (63907, u"'got'")
# (88323, u"o'laughlin")
# (88324, u'nightstick')
# (88325, u'flavoured')
# (86925, u'misdemeanours')
# (10938, u'handedly')
# (51910, u'highwater')
# (86932, u'perplexedly')
# (51912, u'tarred')
# (88327, u"imposter's")
# (40775, u'insouciance')
# (51913, u'cyclist')
# (88328, u"lestrade's")
# (13879, u'metro')
# (18502, u'spiced')
# (55145, u'hulled')
# (88329, u'microman')
# (27526, u'evading')
# (51914, u'bickers')
# (51915, u"'dog")
# (20590, u'simpleton')
# (40776, u"'devil'")
# (25155, u'spices')
# (34670, u"'don")
# (40561, u'initials')
# (88332, u'appearently')
# (7692, u'apple')
# (40777, u'miscreant')
# (51917, u'dwarves')
# (40778, u'overbaked')
# (16109, u'offends')
# (16810, u'herzog')
# (88333, u'ghim')
# (88334, u'cataclysms')
# (11035, u'motor')
# (86996, u'motos')
# (6791, u'apply')
# (88336, u'chandelere')
# (51918, u'rumiko')
# (51919, u'iced')
# (70359, u'yowling')
# (40570, u'hagerty')
# (88338, u'enging')
# (88339, u'reanimating')
# (9180, u'slug')
# (88340, u'ices')
# (40779, u'metzger')
# (14353, u'weeping')
# (8287, u'december')
# (30549, u"sun's")
# (88341, u"'starred'")
# (25219, u'briers')
# (51510, u'brazilians')
# (18503, u'porch')
# (40780, u'credulous')
# (40781, u'philanderer')
# (88343, u"'austin")
# (16811, u'cooperate')
# (30550, u"ruby's")
# (88344, u"'talky'")
# (78708, u'avtar')
# (19489, u'faultless')
# (36249, u'echos')
# (9090, u'penis')
# (40782, u'paralleled')
# (40783, u"ice'")
# (12603, u'slaps')
# (40784, u"cgi'd")
# (88345, u'foggiest')
# (87071, u'5years')
# (15244, u'wildest')
# (88347, u'demonically')
# (88348, u'finacier')
# (58127, u'tpb')
# (21241, u'biscuit')
# (30551, u'proog')
# (34671, u'dedicates')
# (21895, u'tat')
# (88350, u'tau')
# (25220, u'arlen')
# (3929, u'tap')
# (19490, u'tar')
# (12179, u'tas')
# (23371, u'earnestness')
# (21896, u'matinee')
# (88352, u'dummee')
# (27618, u'forays')
# (40786, u'tay')
# (51920, u'taz')
# (88353, u'germanish')
# (4415, u'tad')
# (40583, u'tae')
# (33922, u'g\xf6ta')
# (4346, u'tag')
# (88355, u'condescend')
# (30552, u'shipping')
# (23372, u'tab')
# (40787, u'tac')
# (51921, u'tal')
# (30446, u'recklessly')
# (1432, u'serial')
# (88356, u'tao')
# (87115, u'tah')
# (88357, u'tai')
# (34672, u'taj')
# (34673, u'tak')
# (88358, u'twizzlers')
# (88359, u"'tinker")
# (51923, u'inaugural')
# (7575, u'fortunate')
# (30553, u'japs')
# (51924, u'actualities')
# (88360, u'testators')
# (25221, u'japp')
# (41684, u'ibanez')
# (88362, u'taylors')
# (4076, u'panic')
# (18504, u'inflated')
# (88363, u"'drama")
# (15480, u'discomfort')
# (48760, u'sightseeing')
# (51925, u'footpath')
# (25222, u'skullduggery')
# (51926, u"blaine's")
# (51927, u'gaijin')
# (51928, u'fortinbras')
# (11584, u'crawling')
# (19683, u'starlets')
# (46432, u"mahatma's")
# (23314, u'pah')
# (49084, u'destructiveness')
# (88368, u'cumpsty')
# (51929, u'elio')
# (25223, u'unjustified')
# (88369, u'trophies')
# (25224, u'scoggins')
# (88370, u"'machinal'")
# (88371, u'archiological')
# (6351, u'underwater')
# (14354, u'gunslinger')
# (51930, u'meir')
# (6625, u'reeve')
# (88373, u'voiceless')
# (88374, u'byw')
# (88375, u'terriers')
# (40788, u'byu')
# (87251, u'bys')
# (87258, u"metzger's")
# (5455, u'bye')
# (72547, u'streamwood')
# (19491, u'violating')
# (2484, u'crash')
# (4285, u'practice')
# (14895, u'commended')
# (8238, u'knights')
# (88378, u"caliban's")
# (34675, u'commender')
# (88379, u"melbourne's")
# (40790, u'183')
# (27619, u'sinners')
# (51931, u'cauffiel')
# (88380, u'transmitter')
# (88381, u'easel')
# (88382, u'whiteclad')
# (67103, u'sinnister')
# (7092, u'auto')
# (88383, u'puya')
# (87311, u'puyn')
# (34676, u'tran')
# (16093, u'transmitted')
# (3624, u'trap')
# (51932, u"by'")
# (10995, u'180')
# (51606, u'eases')
# (51933, u'upheavals')
# (84561, u'cleverless')
# (19492, u'pitying')
# (40572, u'woodsmen')
# (16111, u'bentley')
# (63915, u'pallance')
# (88387, u'ponderance')
# (54048, u'bhand')
# (25226, u'apophis')
# (51934, u'fusing')
# (88388, u'bhang')
# (88389, u'celticism')
# (88390, u'achile')
# (73285, u'mstifyed')
# (88392, u"breathnach's")
# (87351, u'stanly')
# (9091, u'pam')
# (51935, u'siani')
# (40791, u'phoebus')
# (51936, u'flapjack')
# (2382, u'category')
# (30555, u'puertorican')
# (38663, u"'best")
# (34678, u'dispossessed')
# (51937, u"montand's")
# (9628, u'garcia')
# (88395, u"franko's")
# (12604, u'outings')
# (51938, u'obstructions')
# (23173, u'dominion')
# (51939, u"daria's")
# (40792, u'grits')
# (16812, u'poets')
# (2102, u'brilliantly')
# (66387, u'riddick')
# (88067, u'swings\x97but')
# (14355, u'dictionary')
# (23373, u'nuit')
# (88396, u"ashram's")
# (34679, u'abductor')
# (88397, u'displeasing')
# (88398, u'obliteration')
# (42358, u'by\x85')
# (51941, u'bedazzled')
# (19493, u'kober')
# (87424, u'rackaroll')
# (88400, u'cait')
# (88401, u"outing'")
# (34680, u'segregated')
# (88403, u'substantiate')
# (88404, u'reexamined')
# (25227, u'horace')
# (88405, u"'oldest")
# (51995, u'brundage')
# (88406, u'inseglet')
# (51943, u'caio')
# (7914, u'cain')
# (31925, u'californian')
# (88407, u"critique's")
# (40793, u'timbers')
# (25229, u'firehouse')
# (34681, u"wenders'")
# (40794, u'jarrell')
# (88408, u'afgan')
# (25230, u'bleakness')
# (88409, u'homere')
# (51944, u'treaters')
# (31001, u"garner's")
# (51945, u'185')
# (25231, u'gratuitously')
# (31443, u'l\xe8vres')
# (88411, u'harmlessness')
# (13867, u'probation')
# (88413, u'homers')
# (88414, u'garard')
# (27621, u'destinations')
# (16813, u'flourish')
# (25232, u'myspace')
# (1188, u'accent')
# (88415, u'weberian')
# (88416, u'drood')
# (14356, u'drool')
# (88417, u'darma')
# (5554, u'thread')
# (88418, u'elbowroom')
# (40795, u'peoria')
# (16112, u'kiera')
# (25233, u'resurrects')
# (50039, u"sheep'")
# (470, u'wanted')
# (88419, u'constituent')
# (40797, u'evisceration')
# (40798, u"flik's")
# (88420, u'osenniy')
# (51946, u'scryeeee')
# (76077, u'nationalistic')
# (51948, u'swooned')
# (4041, u'tommy')
# (88421, u'morely')
# (51949, u'leticia')
# (40106, u'harald')
# (17626, u'sculpture')
# (51950, u'bodice')
# (88422, u'beter')
# (34683, u"1992's")
# (27206, u'outsmarted')
# (88423, u'clevage')
# (88424, u'wathced')
# (40799, u'woebegone')
# (17611, u'alfonso')
# (88426, u'pealed')
# (51951, u'alfonse')
# (88427, u'florin')
# (13881, u'forthcoming')
# (51952, u'florid')
# (63920, u"'gregory's")
# (17627, u'oozing')
# (5744, u'agency')
# (51953, u'zhukov')
# (74220, u'divorc\xe9es')
# (88429, u'desando')
# (88430, u'maharashtrian')
# (26664, u'spawns')
# (88431, u'stying')
# (88432, u"den'")
# (18506, u'divers')
# (57589, u"theme'")
# (40800, u'salkow')
# (18338, u'adamson')
# (5923, u'centre')
# (71522, u"'dim'")
# (73678, u"brynhild's")
# (88436, u'doyleluver')
# (39608, u'1881')
# (40162, u'slitting')
# (30556, u"eustache's")
# (6107, u'deny')
# (40801, u"mcelwee's")
# (88438, u"quiroz's")
# (88439, u'jpieczanski')
# (78164, u'belphegor')
# (88441, u'dens')
# (88442, u'syncretism')
# (87659, u"oozin'")
# (51954, u'goodhearted')
# (23374, u'dent')
# (25234, u'xavier')
# (88444, u'dena')
# (4482, u'inane')
# (88445, u'mckellar')
# (51712, u"word'")
# (87692, u'nailgun')
# (7798, u'myrna')
# (31264, u'illuminations')
# (88447, u'camion')
# (51955, u'waddlesworth')
# (88448, u'laughers')
# (88449, u'playbook')
# (12996, u'powerhouse')
# (88450, u'500db')
# (40804, u'holistic')
# (57743, u'foreclosure')
# (87713, u'disgracing')
# (88452, u'asterix')
# (51956, u"generation'")
# (448, u'fans')
# (40805, u'humanitarian')
# (9455, u'candidates')
# (51957, u'lassiter')
# (78083, u"troops'")
# (3083, u'thousands')
# (88454, u'forfeit')
# (20126, u'philipps')
# (52510, u'merchandises')
# (51958, u'shlocky')
# (69930, u'herinteractive')
# (21897, u'goosebumps')
# (51959, u"skogland's")
# (40806, u'winsor')
# (88457, u'998')
# (88458, u'woooooo')
# (47980, u'bulimics')
# (51960, u'bluray')
# (20575, u"maker's")
# (17628, u'wordy')
# (51961, u'swindle')
# (88459, u"candidate'")
# (88460, u'mulford')
# (88461, u'sappily')
# (34685, u'waterfalls')
# (88462, u'jansch')
# (2185, u'asian')
# (5119, u'generations')
# (30558, u'ebb')
# (87813, u"astronaut's")
# (50042, u'seeded')
# (88465, u'detatched')
# (30559, u'paulson')
# (88466, u"'80ies")
# (14357, u'violet')
# (88467, u'gutters')
# (88468, u'scoured')
# (51962, u'etchings')
# (82107, u"'japonese")
# (83264, u'word\x85')
# (11036, u'closes')
# (62088, u"god\x85yes'")
# (4250, u'closet')
# (88471, u'magus')
# (88472, u'eggleston')
# (1259, u'genius')
# (34686, u'ashleigh')
# (51963, u'rumblings')
# (40807, u'panty')
# (4587, u'closed')
# (51964, u'dividends')
# (27624, u'simms')
# (3974, u'brosnan')
# (51965, u'linebacker')
# (10552, u'complement')
# (4515, u'pants')
# (88474, u'addio')
# (65929, u'99\xbd')
# (51966, u'audiovisual')
# (21898, u'beverages')
# (17629, u'brigadoon')
# (40808, u'salesgirl')
# (63417, u'99\xa2')
# (88475, u'doesnot')
# (13882, u'sexploitation')
# (88476, u"jame's")
# (19494, u'memento')
# (4249, u'voight')
# (30560, u'soapbox')
# (40809, u'famke')
# (5398, u'profanity')
# (40713, u'broadside')
# (2785, u'prefer')
# (18972, u"'30's")
# (88480, u"concert'")
# (34687, u'clansmen')
# (51968, u'agito')
# (7475, u'safely')
# (88482, u'kaempfen')
# (30513, u'withdraws')
# (88483, u'invetigator')
# (34688, u'sleaziest')
# (88484, u'guerin')
# (9876, u'inflicted')
# (88485, u'neighborliness')
# (16113, u'withdrawn')
# (88486, u'withdrawl')
# (87940, u'bbm')
# (22524, u'irreverence')
# (23359, u'klara')
# (88489, u'bbe')
# (2983, u'bbc')
# (11357, u'immortality')
# (51969, u'validating')
# (51970, u'suffocate')
# (88491, u'jugars')
# (81264, u'mambo\x85')
# (88492, u'impetuously')
# (88493, u'thumbes')
# (51971, u'bbs')
# (34690, u'bbq')
# (23375, u'butchers')
# (88494, u'verizon')
# (40810, u'butchery')
# (88495, u"genie's")
# (4042, u'meaningless')
# (88496, u'saner')
# (51972, u"'prestige'")
# (48235, u'revivalist')
# (40811, u"carface's")
# (88497, u"'deepness'")
# (88498, u"agreement'")
# (88499, u'aiieeee')
# (39208, u"sons'")
# (27588, u'irate')
# (80934, u'intresting')
# (76453, u'readies')
# (88503, u'nilamben')
# (34692, u'sebastien')
# (88504, u'funnist')
# (39736, u'marshmorton')
# (49212, u'melo')
# (51973, u"marcel's")
# (88505, u'restructure')
# (88506, u'madrasi')
# (81288, u'piteously')
# (40812, u'garda')
# (40813, u"biggie's")
# (69061, u'insecurities\x85')
# (40814, u'gassing')
# (34693, u'stadiums')
# (6626, u'vintage')
# (51975, u'loutishness')
# (18507, u'headlight')
# (88509, u'nwhere')
# (19495, u'adverse')
# (51976, u'merciful')
# (20594, u'panning')
# (40815, u'keneth')
# (88510, u'fomentation')
# (88511, u'hopton')
# (51977, u"sousa's")
# (51978, u'tactful')
# (88512, u'booz')
# (88513, u'craigs')
# (88577, u'transacting')
# (88514, u'brumes')
# (16814, u'snatchers')
# (51979, u"'cartoons'")
# (88515, u'baruc')
# (88516, u'albin')
# (71927, u"'masters")
# (88517, u'antipasto')
# (88518, u'overwork')
# (88519, u'appropriates')
# (76094, u'equivalencing')
# (40816, u'outgrow')
# (17630, u'breaker')
# (51981, u'boor')
# (27601, u'contenders')
# (9877, u'rocker')
# (88522, u"arcand's")
# (74296, u'gleason\x85')
# (4347, u'rocket')
# (88523, u'wren')
# (51982, u'lowlights')
# (88139, u'cloaks')
# (4884, u'mighty')
# (88525, u'hmapk')
# (11939, u'rocked')
# (34694, u'downfalls')
# (35318, u'shigeru')
# (19496, u'disturbance')
# (12605, u'serbs')
# (22958, u'ensued')
# (1746, u'sky')
# (21900, u'morbidly')
# (51983, u'googling')
# (82114, u"'intentional'")
# (8286, u'clyde')
# (51984, u'ska')
# (88528, u'timecrimes')
# (88529, u'serbo')
# (16114, u'ski')
# (30562, u'knob')
# (25238, u'saturation')
# (34260, u"andr\xe9's")
# (9456, u'branch')
# (54834, u'refusals')
# (21901, u'protesters')
# (8774, u'kristofferson')
# (51985, u'siemens')
# (53304, u'deviances')
# (121, u'know')
# (30563, u'knot')
# (9311, u'knox')
# (59844, u'\xc5ge')
# (40817, u'renyolds')
# (17631, u'iberia')
# (88531, u"annabelle's")
# (40818, u'bedfellows')
# (88532, u'praarthana')
# (88533, u'losted')
# (70961, u'cloistering')
# (4200, u'dances')
# (88534, u"one''willard'")
# (5382, u'servant')
# (88536, u'isolytic')
# (2681, u'starred')
# (27626, u'traitors')
# (25239, u'amores')
# (12257, u'shabby')
# (717, u'sequence')
# (23376, u"matrix'")
# (51986, u'birthmark')
# (34696, u'mosquitoes')
# (34697, u'libretto')
# (13418, u'kattan')
# (34664, u'holler')
# (34040, u'soninha')
# (88287, u'nilsen')
# (88539, u'dubbers')
# (55997, u'mancoy')
# (51988, u"gettin'")
# (17632, u'zanuck')
# (51989, u'leaded')
# (29326, u'strolls')
# (40820, u'moguls')
# (88540, u'catepillar')
# (40821, u'sette')
# (2118, u'leader')
# (23377, u'murdock')
# (88541, u'uneffective')
# (51990, u'haywood')
# (88542, u'miniskirts')
# (88543, u'pensaba')
# (88544, u'thoroughfare')
# (51991, u"o'donoghugh")
# (76917, u'arganauts')
# (88545, u'swinginest')
# (30548, u'hitchhiking')
# (7915, u'wesley')
# (88546, u'daud')
# (30564, u'guffaws')
# (88547, u'empahh')
# (30565, u'nationalities')
# (8594, u'throne')
# (88548, u'intercontenital')
# (51992, u'throng')
# (394, u'getting')
# (51993, u'klineschloss')
# (21902, u'dependence')
# (25240, u'dependency')
# (19497, u'epiphany')
# (25241, u'fudd')
# (76097, u'wonk')
# (88549, u'fitzgibbon')
# (27627, u'bugle')
# (88550, u'unoticeable')
# (24879, u'couldnt')
# (30566, u'gunther')
# (57756, u'cultureless')
# (88551, u"'hall")
# (88386, u"'dollman'")
# (21903, u'registration')
# (30567, u'madhavi')
# (3426, u'fired')
# (51994, u'patronisingly')
# (88554, u'maize')
# (21904, u'uncontrollably')
# (88555, u'expeditious')
# (51942, u'noxious')
# (27628, u'hypnotism')
# (88556, u"'half")
# (88557, u'lederer')
# (14359, u'uncontrollable')
# (34698, u'footwork')
# (204, u"i've")
# (5974, u'proving')
# (42569, u'worriedly')
# (40824, u'baaaaad')
# (44477, u'gereco')
# (88558, u"bearings'")
# (51997, u'kensit')
# (88559, u'wight')
# (34699, u'brashness')
# (51998, u'bratwurst')
# (14128, u"may's")
# (88560, u'contradictors')
# (88561, u'amitabhs')
# (19498, u'jaffa')
# (11924, u'jaffe')
# (40826, u'instructive')
# (88562, u"olan's")
# (51999, u'ornella')
# (57759, u'bitva')
# (88564, u'reble')
# (88565, u'percival')
# (88566, u'lubricated')
# (34700, u"matsumoto's")
# (88567, u'heralding')
# (52001, u'hirschbiegel')
# (88568, u"baywatch'")
# (88569, u'odilon')
# (18508, u'vans')
# (40827, u'gnawing')
# (63863, u"markham's")
# (88571, u"guard's")
# (88572, u"nemesis'")
# (57761, u'spookfest')
# (54907, u"'transporter'")
# (88573, u'airsoft')
# (11306, u'abhay')
# (23378, u'spanky')
# (88575, u'ev')
# (88576, u'chicatillo')
# (34064, u"dance'")
# (27630, u"'la")
# (8925, u'percent')
# (7996, u'oprah')
# (88578, u'sics')
# (11925, u'illinois')
# (40828, u'dogtown')
# (20595, u'roars')
# (1192, u'sick')
# (52002, u'kerouac')
# (88579, u'wheelers')
# (20596, u'sica')
# (6435, u'lance')
# (88580, u"pipe's")
# (64179, u'discretionary')
# (40829, u'contends')
# (88581, u'copywrite')
# (52003, u'geysers')
# (88582, u'artbox')
# (51107, u'cl\xe9ment')
# (52004, u'cronyn')
# (52005, u'hardboiled')
# (88583, u"voorhees'")
# (16815, u'35mm')
# (88584, u"'l'")
# (88574, u'urrrghhh')
# (20597, u'expands')

# %%
word_dict['aileen']
# Out:
# 19313

# %% [markdown]
# ## Build Keras Embedding Layer Model
# We can think of the Embedding layer as a dicionary that maps a index assigned to a word to a word vector. This layer is very flexible and can be used in a few ways:
#
# * The embedding layer can be used at the start of a larger deep learning model.
# * Also we could load pre-train word embeddings into the embedding layer when we create our model.
# * Use the embedding layer to train our own word2vec models.
#
# The keras embedding layer doesn't require us to onehot encode our words, instead we have to give each word a unqiue intger number as an id. For the imdb dataset we've loaded this has already been done, but if this wasn't the case we could use sklearn [LabelEncoder](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence

# %%
# !pip install -U protobuf==3.8.0
# Out:
# Collecting protobuf==3.8.0
#   Downloading https://files.pythonhosted.org/packages/b2/a8/ad407cd2a56a052d92f602e164a9e16bede22079252af0db3838f375b6a8/protobuf-3.8.0-cp27-cp27mu-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 9.7MB/s
# Requirement already satisfied, skipping upgrade: six>=1.9 in /tensorflow-2.1.0/python2.7 (from protobuf==3.8.0) (1.14.0)
# Requirement already satisfied, skipping upgrade: setuptools in /tensorflow-2.1.0/python2.7 (from protobuf==3.8.0) (44.0.0)
# Installing collected packages: protobuf
#   Found existing installation: protobuf 3.11.3
#     Uninstalling protobuf-3.11.3:
#       Successfully uninstalled protobuf-3.11.3
# Successfully installed protobuf-3.8.0

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32, input_length=maxlen))
model.add(Flatten())
model.add(Dense(250, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 300, 32)           320000
# _________________________________________________________________
# flatten (Flatten)            (None, 9600)              0
# _________________________________________________________________
# dense (Dense)                (None, 250)               2400250
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 251
# =================================================================
# Total params: 2,720,501
# Trainable params: 2,720,501
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=128, verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 - 3s - loss: 0.0238 - accuracy: 0.9950 - val_loss: 0.4315 - val_accuracy: 0.8623
# Epoch 2/10
# 25000/25000 - 3s - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.4838 - val_accuracy: 0.8657
# Epoch 3/10
# 25000/25000 - 3s - loss: 9.1750e-04 - accuracy: 1.0000 - val_loss: 0.5124 - val_accuracy: 0.8671
# Epoch 4/10
# 25000/25000 - 3s - loss: 4.9159e-04 - accuracy: 1.0000 - val_loss: 0.5363 - val_accuracy: 0.8682
# Epoch 5/10
# 25000/25000 - 3s - loss: 3.2236e-04 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8680
# Epoch 6/10
# 25000/25000 - 3s - loss: 2.2864e-04 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 0.8683
# Epoch 7/10
# 25000/25000 - 3s - loss: 1.6801e-04 - accuracy: 1.0000 - val_loss: 0.5836 - val_accuracy: 0.8688
# Epoch 8/10
# 25000/25000 - 3s - loss: 1.2824e-04 - accuracy: 1.0000 - val_loss: 0.5972 - val_accuracy: 0.8690
# Epoch 9/10
# 25000/25000 - 3s - loss: 1.0118e-04 - accuracy: 1.0000 - val_loss: 0.6087 - val_accuracy: 0.8694
# Epoch 10/10
# 25000/25000 - 3s - loss: 8.0813e-05 - accuracy: 1.0000 - val_loss: 0.6199 - val_accuracy: 0.8695

# %%
scores = model.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 86.95%

# %% [markdown]
# ## Retrive the output of each layer in keras for a given single test sample from the trained model you built

# %%
from tensorflow.keras import backend as K

inp = model.input                                           # input placeholder
outputs = [layer.output for layer in model.layers]          # all layer outputs
functor = K.function([inp, K.learning_phase()], outputs )   # evaluation function

# Testing
test = x_train[0]
layer_outs = functor([test, 1.])
print layer_outs
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-16-9fe03707d3a0> in <module>()
#       3 inp = model.input                                           # input placeholder
#       4 outputs = [layer.output for layer in model.layers]          # all layer outputs
# ----> 5 functor = K.function([inp, K.learning_phase()], outputs )   # evaluation function
#       6
#       7 # Testing
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/keras/backend.pyc in function(inputs, outputs, updates, name, **kwargs)
#    3758       raise ValueError('Session keyword arguments are not support during '
#    3759                        'eager execution. You passed: %s' % (kwargs,))
# -> 3760     return EagerExecutionFunction(inputs, outputs, updates=updates, name=name)
#    3761
#    3762   if kwargs:
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/keras/backend.pyc in __init__(self, inputs, outputs, updates, name)
#    3655             add_sources=True,
#    3656             handle_captures=True,
# -> 3657             base_graph=source_graph)
#    3658
#    3659         inputs = [lifted_map[i] for i in inputs]
#
# /tensorflow-2.1.0/python2.7/tensorflow_core/python/eager/lift_to_graph.pyc in lift_to_graph(tensors, graph, sources, disallowed_placeholders, add_sources, handle_captures, base_graph, op_map)
#     247   # Check that the initializer does not depend on any placeholders.
#     248   sources = object_identity.ObjectIdentitySet(sources or [])
# --> 249   visited_ops = set([x.op for x in sources])
#     250   op_outputs = collections.defaultdict(set)
#     251
#
# AttributeError: 'int' object has no attribute 'op'
